# %% [markdown]
# # Skeleton Code for the Final Project
#
# Github repo link: https://github.com/GSDSAML/prompt-engineering-2024fall/tree/main

# %% [markdown]
# ## Leaderboard
#
# Leaderboard updated from the Github repo.

# %%
import requests

url = "https://raw.githubusercontent.com/GSDSAML/prompt-engineering-2024fall/refs/heads/main/final_project/leaderboard.csv"
response = requests.get(url)

with open("leaderboard.csv", "wb") as file:
    file.write(response.content)

print("File downloaded successfully.")
# Out:
# File downloaded successfully.

# %%
import pandas as pd

# Load the leaderboard.csv file into a pandas DataFrame.
df = pd.read_csv('leaderboard.csv')

df
# Out:
#    group_number  score  ranking   update_dt
# 0             0    0.2        1  2024-12-03
# 1            15    0.0        2  2024-12-03

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### You can download the FinQA train and test set here

# %%
# !wget https://github.com/czyssrs/FinQA/raw/refs/heads/main/dataset/train.json
# Out:
# 'wget' ���O�����Υ~���R�O�B�i���檺�{���Χ妸�ɡC

# %%
# !wget https://github.com/czyssrs/FinQA/raw/refs/heads/main/dataset/test.json
# Out:
# 'wget' ���O�����Υ~���R�O�B�i���檺�{���Χ妸�ɡC

# %% [markdown]
# ## Environment Setup

# %%
# Install langchain
# !pip install --quiet  langchain langchain-community langchainhub langchain-openai langchain-chroma bs4
# Out:
# WARNING: Ignoring invalid distribution ~umpy (D:\Users\mindy\anaconda3\envs\prompt\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\Users\mindy\anaconda3\envs\prompt\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\Users\mindy\anaconda3\envs\prompt\Lib\site-packages)

# %%
# !pip uninstall -y openai langchain langchain-openai
# !pip install openai==0.27.8
# !pip install langchain
# !pip install langchain-openai
# Out:
# Found existing installation: openai 1.57.1
# Uninstalling openai-1.57.1:
#   Successfully uninstalled openai-1.57.1
# Found existing installation: langchain 0.3.10
# Uninstalling langchain-0.3.10:
#   Successfully uninstalled langchain-0.3.10
# Found existing installation: langchain-openai 0.2.12
# Uninstalling langchain-openai-0.2.12:
#   Successfully uninstalled langchain-openai-0.2.12
# Collecting openai==0.27.8
#   Using cached openai-0.27.8-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.20 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from openai==0.27.8) (2.32.3)
# Requirement already satisfied: tqdm in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from openai==0.27.8) (4.67.1)
# Requirement already satisfied: aiohttp in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from openai==0.27.8) (3.11.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from requests>=2.20->openai==0.27.8) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from requests>=2.20->openai==0.27.8) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from requests>=2.20->openai==0.27.8) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from requests>=2.20->openai==0.27.8) (2024.8.30)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from aiohttp->openai==0.27.8) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from aiohttp->openai==0.27.8) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from aiohttp->openai==0.27.8) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from aiohttp->openai==0.27.8) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from aiohttp->openai==0.27.8) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from aiohttp->openai==0.27.8) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from aiohttp->openai==0.27.8) (1.18.3)
# Requirement already satisfied: colorama in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from tqdm->openai==0.27.8) (0.4.6)
# Using cached openai-0.27.8-py3-none-any.whl (73 kB)
# Installing collected packages: openai
# Successfully installed openai-0.27.8
# WARNING: Ignoring invalid distribution ~umpy (D:\Users\mindy\anaconda3\envs\prompt\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\Users\mindy\anaconda3\envs\prompt\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\Users\mindy\anaconda3\envs\prompt\Lib\site-packages)
# Collecting langchain
#   Downloading langchain-0.3.11-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain) (3.11.10)
# Collecting langchain-core<0.4.0,>=0.3.24 (from langchain)
#   Downloading langchain_core-0.3.24-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain) (0.1.147)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\mindy\appdata\roaming\python\python311\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain) (2.10.3)
# Requirement already satisfied: requests<3,>=2 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain-core<0.4.0,>=0.3.24->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain-core<0.4.0,>=0.3.24->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain-core<0.4.0,>=0.3.24->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (4.7.0)
# Requirement already satisfied: httpcore==1.* in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.24->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.3.1)
# Downloading langchain-0.3.11-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 15.9 MB/s eta 0:00:00
# Downloading langchain_core-0.3.24-py3-none-any.whl (410 kB)
# Installing collected packages: langchain-core, langchain
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.22
#     Uninstalling langchain-core-0.3.22:
#       Successfully uninstalled langchain-core-0.3.22
# Successfully installed langchain-0.3.11 langchain-core-0.3.24
# WARNING: Ignoring invalid distribution ~umpy (D:\Users\mindy\anaconda3\envs\prompt\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\Users\mindy\anaconda3\envs\prompt\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\Users\mindy\anaconda3\envs\prompt\Lib\site-packages)
# Collecting langchain-openai
#   Using cached langchain_openai-0.2.12-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain-openai) (0.3.24)
# Collecting openai<2.0.0,>=1.55.3 (from langchain-openai)
#   Downloading openai-1.57.2-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: tiktoken<1,>=0.7 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain-openai) (0.8.0)
# Requirement already satisfied: PyYAML>=5.3 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (0.1.147)
# Requirement already satisfied: packaging<25,>=23.2 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (2.10.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from openai<2.0.0,>=1.55.3->langchain-openai) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from openai<2.0.0,>=1.55.3->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from openai<2.0.0,>=1.55.3->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from openai<2.0.0,>=1.55.3->langchain-openai) (0.8.2)
# Requirement already satisfied: sniffio in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from openai<2.0.0,>=1.55.3->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from openai<2.0.0,>=1.55.3->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.55.3->langchain-openai) (3.10)
# Requirement already satisfied: certifi in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.55.3->langchain-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.55.3->langchain-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.55.3->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.21->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.21->langchain-openai) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.21->langchain-openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.21->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.21->langchain-openai) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.3)
# Requirement already satisfied: colorama in d:\users\mindy\anaconda3\envs\prompt\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.55.3->langchain-openai) (0.4.6)
# Using cached langchain_openai-0.2.12-py3-none-any.whl (50 kB)
# Downloading openai-1.57.2-py3-none-any.whl (389 kB)
# Installing collected packages: openai, langchain-openai
#   Attempting uninstall: openai
#     Found existing installation: openai 0.27.8
#     Uninstalling openai-0.27.8:
#       Successfully uninstalled openai-0.27.8
# Successfully installed langchain-openai-0.2.12 openai-1.57.2
# WARNING: Ignoring invalid distribution ~umpy (D:\Users\mindy\anaconda3\envs\prompt\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\Users\mindy\anaconda3\envs\prompt\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\Users\mindy\anaconda3\envs\prompt\Lib\site-packages)

# %% [markdown]
# ### Set API key

# %% [markdown]
# ### Prepare model

# %%
# Prepare model
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.0, api_key=OPENAI_API_KEY)

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Download and unzip backup vector DB
#
# *   Source dataset: [FinQA](https://finqasite.github.io/)
# *   EDA for the FinQA dataset: https://medium.com/@sohilsharma1996/finqa-project-numerical-reasoning-over-financial-data-77a3fb4133d2
#
# You can build your own vector DB for retrieval.

# %%
# !wget https://github.com/GSDSAML/prompt-engineering-2024fall/raw/refs/heads/main/final_project/db.zip
# Out:
# 'wget' ���O�����Υ~���R�O�B�i���檺�{���Χ妸�ɡC

# %%
# !unzip db.zip
# Out:
# 'unzip' ���O�����Υ~���R�O�B�i���檺�{���Χ妸�ɡC

# %% [markdown]
# ### Fiscal year end date dictionary
#
# Collected from SEC EDGAR
#
# Dictionary with Key(ticker): Value(Fiscal year end date)
#
# Actually, the date may different every year, but we will use this for now.

# %%
company_fiscal_year_end = {'GIS': '0530', 'FRT': '1231', 'MMM': '1231', 'K': '1228', 'INTC': '1228', 'CAG': '0525', 'MSI': '1231', 'FIS': '1231', 'CCI': '1231', 'CDW': '1231', 'GPN': '1231', 'TMUS': '1231', 'D': '1231', 'KMI': '1231', 'NTAP': '0426', 'TSCO': '1230', 'BLK': '1231', 'CNC': '1231', 'MRK': '1231', 'JKHY': '0630', 'VTR': '1231', 'GRMN': '1228', 'AMT': '1231', 'MAR': '1231', 'HIG': '1231', 'ADI': '1102', 'ILMN': '1229', 'NKE': '0531', 'VNO': '1231', 'FITB': '1231', 'ETR': '1231', 'KIM': '1231', 'AMAT': '1027', 'OKE': '1231', 'DG': '0131', 'TFX': '1231', 'AAL': '1231', 'EXPD': '1231', 'V': '0930', 'REGN': '1231', 'PPG': '1231', 'RCL': '1231', 'VLO': '1231', 'KHC': '1228', 'HUM': '1231', 'WELL': '1231', 'ALLE': '1231', 'UNP': '1231', 'LLY': '1231', 'TXN': '1231', 'GS': '1231', 'LKQ': '1231', 'SYY': '0629', 'IPG': '1231', 'AAP': '1228', 'ECL': '1231', 'MKTX': '1231', 'C': '1231', 'ZBH': '1231', 'UAA': '0331', 'MRO': '1231', 'AON': '1231', 'SPGI': '1231', 'ORLY': '1231', 'MO': '1231', 'PM': '1231', 'BKNG': '1231', 'BKR': '1231', 'AWK': '1231', 'APTV': '1231', 'WRK': '0930', 'SWKS': '0927', 'CMCSA': '1231', 'CE': '1231', 'CB': '1231', 'WMT': '0131', 'STT': '1231', 'RSG': '1231', 'AOS': '1231', 'AAPL': '0928', 'EXR': '1231', 'UA': '0331', 'CME': '1231', 'HII': '1231', 'HOLX': '0928', 'SLB': '1231', 'EW': '1231', 'EMR': '0930', 'VRTX': '1231', 'APD': '0930', 'ADBE': '1129', 'CAT': '1231', 'PNC': '1231', 'MAA': '1231', 'AES': '1231', 'SNA': '1228', 'JPM': '1231', 'NCLH': '1231', 'PKG': '1231', 'TROW': '1231', 'HST': '1231', 'NWS': '0630', 'MA': '1231', 'DVN': '1231', 'ANSS': '1231', 'ANET': '1231', 'SNPS': '1031', 'RL': '0328', 'DISH': '1231', 'HWM': '1231', 'FTV': '1231', 'L': '1231', 'LMT': '1231', 'MAS': '1231', 'STZ': '0228', 'EMN': '1231', 'CDNS': '1231', 'EL': '0630', 'SLG': '1231', 'BDX': '0930', 'UPS': '1231', 'MS': '1231', 'IQV': '1231', 'IP': '1231', 'EOG': '1231'}

# %% [markdown]
# ## Define Tools

# %% [markdown]
# ### LangChain Tool Use Example
#
# List of pre-defined tools in LangChain: https://python.langchain.com/docs/integrations/tools/

# %%
from langchain_core.tools import tool


@tool
def multiply(a: int, b: int) -> int:
    """Multiply two numbers."""
    return a * b


# Let's inspect some of the attributes associated with the tool.
print(multiply.name)
print(multiply.description)
print(multiply.args)

@tool
def add(a: int, b: int) -> int:
    """Add two integers."""
    return a + b

print(add.name)
print(add.description)
print(add.args)
# Out:
# multiply
# Multiply two numbers.
# {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}
# add
# Add two integers.
# {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}

# %%
tools = [add, multiply]

# %%
llm_with_tools = llm.bind_tools(tools)

query = "What is 3 * 12?"

llm_with_tools.invoke(query).tool_calls
# Out:
# [{'name': 'multiply',
#   'args': {'a': 3, 'b': 12},
#   'id': 'call_RwY6KWnsW8cEtbfnLr6lMidZ',
#   'type': 'tool_call'}]

# %%
from langchain_core.messages import HumanMessage

query = "What is 3 * 12? Also, what is 11 + 49?"

messages = [HumanMessage(query)]

ai_msg = llm_with_tools.invoke(messages)

print(ai_msg.tool_calls)

messages.append(ai_msg)
# Out:
# [{'name': 'multiply', 'args': {'a': 3, 'b': 12}, 'id': 'call_oG2Zs41ZreHLYvaHzF2zZFfW', 'type': 'tool_call'}, {'name': 'add', 'args': {'a': 11, 'b': 49}, 'id': 'call_441xv8hYIqojX84kSCm7r59F', 'type': 'tool_call'}]

# %%
for tool_call in ai_msg.tool_calls:
    selected_tool = {"add": add, "multiply": multiply}[tool_call["name"].lower()]
    tool_msg = selected_tool.invoke(tool_call)
    messages.append(tool_msg)

messages
# Out:
# [HumanMessage(content='What is 3 * 12? Also, what is 11 + 49?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_oG2Zs41ZreHLYvaHzF2zZFfW', 'function': {'arguments': '{"a": 3, "b": 12}', 'name': 'multiply'}, 'type': 'function'}, {'id': 'call_441xv8hYIqojX84kSCm7r59F', 'function': {'arguments': '{"a": 11, "b": 49}', 'name': 'add'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 83, 'total_tokens': 133, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_6fc10e10eb', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-262f2e98-5785-4b79-89dc-d481851f02eb-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3, 'b': 12}, 'id': 'call_oG2Zs41ZreHLYvaHzF2zZFfW', 'type': 'tool_call'}, {'name': 'add', 'args': {'a': 11, 'b': 49}, 'id': 'call_441xv8hYIqojX84kSCm7r59F', 'type': 'tool_call'}], usage_metadata={'input_tokens': 83, 'output_tokens': 50, 'total_tokens': 133, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='36', name='multiply', tool_call_id='call_oG2Zs41ZreHLYvaHzF2zZFfW'),
#  ToolMessage(content='60', name='add', tool_call_id='call_441xv8hYIqojX84kSCm7r59F')]

# %%
llm_with_tools.invoke(messages).content
# Out:
# 'The result of \\(3 \\times 12\\) is 36, and the result of \\(11 + 49\\) is 60.'

# %% [markdown]
# ### Extract fiscal tool

# %%
company_fiscal_year_end
# Out:
# {'GIS': '0530',
#  'FRT': '1231',
#  'MMM': '1231',
#  'K': '1228',
#  'INTC': '1228',
#  'CAG': '0525',
#  'MSI': '1231',
#  'FIS': '1231',
#  'CCI': '1231',
#  'CDW': '1231',
#  'GPN': '1231',
#  'TMUS': '1231',
#  'D': '1231',
#  'KMI': '1231',
#  'NTAP': '0426',
#  'TSCO': '1230',
#  'BLK': '1231',
#  'CNC': '1231',
#  'MRK': '1231',
#  'JKHY': '0630',
#  'VTR': '1231',
#  'GRMN': '1228',
#  'AMT': '1231',
#  'MAR': '1231',
#  'HIG': '1231',
#  'ADI': '1102',
#  'ILMN': '1229',
#  'NKE': '0531',
#  'VNO': '1231',
#  'FITB': '1231',
#  'ETR': '1231',
#  'KIM': '1231',
#  'AMAT': '1027',
#  'OKE': '1231',
#  'DG': '0131',
#  'TFX': '1231',
#  'AAL': '1231',
#  'EXPD': '1231',
#  'V': '0930',
#  'REGN': '1231',
#  'PPG': '1231',
#  'RCL': '1231',
#  'VLO': '1231',
#  'KHC': '1228',
#  'HUM': '1231',
#  'WELL': '1231',
#  'ALLE': '1231',
#  'UNP': '1231',
#  'LLY': '1231',
#  'TXN': '1231',
#  'GS': '1231',
#  'LKQ': '1231',
#  'SYY': '0629',
#  'IPG': '1231',
#  'AAP': '1228',
#  'ECL': '1231',
#  'MKTX': '1231',
#  'C': '1231',
#  'ZBH': '1231',
#  'UAA': '0331',
#  'MRO': '1231',
#  'AON': '1231',
#  'SPGI': '1231',
#  'ORLY': '1231',
#  'MO': '1231',
#  'PM': '1231',
#  'BKNG': '1231',
#  'BKR': '1231',
#  'AWK': '1231',
#  'APTV': '1231',
#  'WRK': '0930',
#  'SWKS': '0927',
#  'CMCSA': '1231',
#  'CE': '1231',
#  'CB': '1231',
#  'WMT': '0131',
#  'STT': '1231',
#  'RSG': '1231',
#  'AOS': '1231',
#  'AAPL': '0928',
#  'EXR': '1231',
#  'UA': '0331',
#  'CME': '1231',
#  'HII': '1231',
#  'HOLX': '0928',
#  'SLB': '1231',
#  'EW': '1231',
#  'EMR': '0930',
#  'VRTX': '1231',
#  'APD': '0930',
#  'ADBE': '1129',
#  'CAT': '1231',
#  'PNC': '1231',
#  'MAA': '1231',
#  'AES': '1231',
#  'SNA': '1228',
#  'JPM': '1231',
#  'NCLH': '1231',
#  'PKG': '1231',
#  'TROW': '1231',
#  'HST': '1231',
#  'NWS': '0630',
#  'MA': '1231',
#  'DVN': '1231',
#  'ANSS': '1231',
#  'ANET': '1231',
#  'SNPS': '1031',
#  'RL': '0328',
#  'DISH': '1231',
#  'HWM': '1231',
#  'FTV': '1231',
#  'L': '1231',
#  'LMT': '1231',
#  'MAS': '1231',
#  'STZ': '0228',
#  'EMN': '1231',
#  'CDNS': '1231',
#  'EL': '0630',
#  'SLG': '1231',
#  'BDX': '0930',
#  'UPS': '1231',
#  'MS': '1231',
#  'IQV': '1231',
#  'IP': '1231',
#  'EOG': '1231'}

# %% [markdown]
# Extract company ticker from the question
#
# We used LLM for now, but may need to connect DB for stability.

# %%
from langchain_core.prompts import PromptTemplate

extract_ticker_prompt = PromptTemplate(
    input_variables=["question"],
    template="""
    You have to extract the company name in the given question, and answer the ticker of the company.
    Answer in JSON format, with 'ticker' key.

    Question: {question}

    Output JSON: {{
      "ticker": "<ticker of the company>"
    }}
    """
)

from pydantic import BaseModel, Field

class Ticker(BaseModel):
    """Ticker of the company in the given question"""
    ticker: str = Field(description="ticker of the company")

extract_ticker_chain = extract_ticker_prompt | llm.with_structured_output(Ticker)

# %%
extract_ticker_chain.invoke({"question": "What was the revenue of Apple in 2022?"})
# Out:
# Ticker(ticker='AAPL')

# %%
from langchain_core.output_parsers import StrOutputParser
from datetime import datetime

parser = StrOutputParser()

change_prompt = PromptTemplate(
    input_variables=["original_question", "fiscal_info", "today"],
    template="""
    You have to convert relative time information in the given original question to the fiscal year of the company.
    Use the fiscal end date to convert to fiscal year.
    Answer only the converted question.

    Original question: {original_question}
    Fiscal end date for the company: {fiscal_info}
    Today date: {today}
    """
)

convert_chain = change_prompt | llm | parser

def get_fiscal_info_with_ticker(ticker: str) -> str:
    """Get fiscal year information of the company with ticker string."""
    ticker = ticker.upper()
    if ticker in company_fiscal_year_end:
      end_date = company_fiscal_year_end[ticker]
      return end_date[:2] + '-' + end_date[2:]
    else:
      return '12-31'

extract_fiscal_prompt = PromptTemplate(
    input_variables=["question"],
    template="""
    You have to extract the fiscal year in the given question.
    Answer in JSON format, with 'fy' key.

    Question: {question}

    Output JSON: {{
      "fy": <fiscal year in the question>
    }}
    """
)

from pydantic import BaseModel, Field

class FiscalYear(BaseModel):
    """FiscalYear mentioned in the given question"""
    fy: int = Field(description="fiscal year in the question")

extract_fiscal_chain = extract_fiscal_prompt | llm.with_structured_output(FiscalYear)

# %%
from langchain_core.tools import tool
from typing import Tuple, Optional
from pydantic import ValidationError

@tool
def rewrite2fiscal(question: str) -> Tuple[Optional[str], Optional[int]]:
    """
    Extract the company ticker and convert relative time information
    in the question to the fiscal year of the company.

    Args:
        question: The financial question from the user.

    Returns:
        A tuple of (ticker, fiscal year), or (None, None) if extraction fails.
    """
    try:
        # Extract ticker
        ticker_response = extract_ticker_chain.invoke({"question": question})
        ticker = ticker_response.ticker if hasattr(ticker_response, 'ticker') else None

        if not ticker:
            return None, None

        # Get today's date for fiscal year conversion
        today = datetime.now().strftime("%Y-%m-%d")
        fiscal_info = get_fiscal_info_with_ticker(ticker)

        # Convert question to fiscal year-specific query
        response = convert_chain.invoke({
            "original_question": question,
            "fiscal_info": fiscal_info,
            "today": today
        })

        # Extract fiscal year
        fiscal_response = extract_fiscal_chain.invoke({'question': response})
        fy = fiscal_response.fy if hasattr(fiscal_response, 'fy') else None

        return ticker, fy

    except Exception as e:
        print(f"Error in rewrite2fiscal: {e}")
        return None, None

# %% [markdown]
# ### Domain specific calulation tools
#
# You should implement more tools to answer complex questions.

# %%
@tool
def calculate_eps(net_income: float, outstanding_shares: int):
  """Calculate the EPS of the company using net income and outstanding share

   Args:
        net_income: Net income value of the company
        outstanding_shares: Total stock held by the company's shareholders

    Returns:
        EPS value
  """
  if (net_income is None) or (outstanding_shares is None):
    print("Give me the net income and outstanding shares first")
    return None
  elif outstanding_shares == 0:
    print("Outstanding shares cannot be zero")
    return None

  return net_income / outstanding_shares

# %%
@tool
def calculate_cashflowfromoperations(net_income: float, non_cash_items: float, changes_in_working_capital: float):
  """Calculate the cash flow from operations of the company using net income, non cash items and change in working capital

   Args:
        net_income: Net income value of the company
        non_cash_items: Financial transactions or events that are recorded in a company's financial statements but do not involve the exchange of cash
        changes_in_working_capital: Difference in a company's working capital between two reporting periods

    Returns:
        Value of cash flow from operations
  """
  if (net_income is None) or (non_cash_items is None) or (changes_in_working_capital is None):
    print("Give me the net income, non cash items and change in working capital data first")
    return None

  return net_income + non_cash_items + changes_in_working_capital

# %% [markdown]
# ### our own tools

# %%
@tool
def calculate_operating_profit_margin(operating_profit: float, revenue: float):
    """Calculate the operating profit margin of the company.

    Args:
        operating_profit: Profit from business operations (gross profit less operating expenses) before deduction of interest and taxes.
        revenue: Revenue calculated from `calculate_revenue`.

    Returns:
        The operating profit margin, calculated as operating profit divided by revenue.
    """
    if (operating_profit is None) or (revenue is None) or (revenue == 0):
        print("Provide valid operating profit and revenue data first.")
        return None

    return operating_profit / revenue

@tool
def calculate_revenue(sales: float, average_price: float, sales_price: float, operating_revenues: dict):
    """
    Calculate the revenue of the company using sales, average price, and sales price.
    Additionally, calculate the average total operating revenue from the provided operating revenues for each year.

    Args:
        sales: Sales of the company.
        average_price: Average price of the service provided by the company.
        sales_price: Sales price of the company's product.
        operating_revenues: A dictionary where keys are years and values are total operating revenues for those years.

    Returns:
        A tuple containing:
        - Sales multiplied by average price.
        - Sales multiplied by sales price.
        - Average of total operating revenues for all years.
    """
    if (sales is None) or (average_price is None) or (sales_price is None):
        print("Provide sales, average price, and sales price data first.")
        return None

    # Calculate revenues based on sales and prices
    revenue_average_price = sales * average_price
    revenue_sales_price = sales * sales_price

    # Calculate the average of total operating revenues
    if operating_revenues:
        average_operating_revenue = sum(operating_revenues.values()) / len(operating_revenues)
    else:
        print("Provide a valid dictionary of operating revenues.")
        return None

    return revenue_average_price, revenue_sales_price, average_operating_revenue

# %%
@tool
def calculate_current_ratio(current_assets: float, current_liabilities: float):
    """Calculate the current ratio of a company using current assets and current liabilities.

    Args:
        current_assets: All company-owned assets that can be converted to cash within one year, includes cash, cash equivalents, accounts receivables, stock inventory, marketable securities, pre-paid liabilities, and other liquid assets.
        current_liabilities: Company's short-term financial obligations that are due within one year or within a normal operating cycle.

    Returns:
        The current ratio, calculated as current_assets / current_liabilities.
    """
    if (current_assets is None) or (current_liabilities is None):
        print("Provide both current assets and current liabilities data first")
        return None

    if current_liabilities == 0:
        print("Current liabilities cannot be zero to calculate the ratio")
        return None

    return current_assets / current_liabilities

@tool
def calculate_total_assets(total_liabilities: float, total_stockholders_equity: float):
    """Calculate the total assets of a company using total liabilities and total stockholders' equity.

    Args:
        total_liabilities: The combined debts that the company owes.
        total_stockholders_equity: The source of a company's assets, the owners' residual claim of a company's assets after its liabilities have been paid, or the company's total book value.

    Returns:
        The total assets, calculated as total_liabilities + total_stockholders_equity.
    """
    if (total_liabilities is None) or (total_stockholders_equity is None):
        print("Provide both total liabilities and total stockholders' equity data first")
        return None

    return total_liabilities + total_stockholders_equity

# %%
@tool
def calculate_ebt(net_income: float, taxes: float):
    """Calculate the EBT of the company using net income and taxes.

    Args:
        net_income: Sales minus cost of goods sold, general expenses, taxes, and interest.
        taxes: Total taxes paid by the company.

    Returns:
        EBT value (Net income + Taxes).
    """
    if (net_income is None) or (taxes is None):
        print("Provide both net income and taxes.")
        return None

    return net_income + taxes


@tool
def calculate_ebit(revenue: float, cogs: float, operating_expenses: float):
    """Calculate the EBIT of the company using revenue, COGS, and operating expenses.

    Args:
        revenue: Total revenue of the company.
        cogs: Cost of goods sold.
        operating_expenses: Total operating expenses of the company.

    Returns:
        EBIT value (Revenue – COGS – Operating Expenses).
    """
    if (revenue is None) or (cogs is None) or (operating_expenses is None):
        print("Provide revenue, COGS, and operating expenses.")
        return None

    return revenue - cogs - operating_expenses


@tool
def calculate_interest_expenses(calculate_ebit: float, calculate_ebt: float):
    """Calculate the interest expenses using EBIT and EBT.

    Args:
        calculate_ebit: EBIT value of the company.
        calculate_ebt: EBT value of the company.

    Returns:
        Interest expenses (EBIT - EBT).
    """
    if (calculate_ebit is None) or (calculate_ebt is None):
        print("Provide both EBIT and EBT.")
        return None

    return calculate_ebit - calculate_ebt


@tool
def calculate_interest_income(average_cash_and_cash_equivalents: float, cash_rate: float):
    """
    Calculate interest income using cash equivalents and interest rate.

    Args:
        average_cash_and_cash_equivalents: Average of the beginning and ending cash balances.
        cash_rate: Interest rate earned on cash (in percentage).

    Returns:
        Interest income (Average Cash * Cash Rate).
    """
    return average_cash_and_cash_equivalents * (cash_rate / 100)


@tool
def calculate_supplementary_leverage_ratio(liquid_assets: float, demand: float, time_liabilities: float):
    """Calculate the supplementary leverage ratio.

    Args:
        liquid_assets: Assets that can be converted to cash easily.
        demand: Consumer's desire to purchase goods/services.
        time_liabilities: Liabilities repayable after an agreed period.

    Returns:
        Supplementary leverage ratio in percentage.
    """
    if (liquid_assets is None) or (demand is None) or (time_liabilities is None):
        print("Provide liquid assets, demand, and time liabilities.")
        return None

    return (liquid_assets / (demand + time_liabilities)) * 100


@tool
def calculate_weighted_average(number: list, degree_of_importance: list, sum_of_number: float):
    """Calculate the weighted average.

    Args:
        number: A list of points in the dataset.
        degree_of_importance: Weights assigned to each number.
        sum_of_number: Sum of all numbers.

    Returns:
        Weighted average value.
    """
    if (number is None) or (degree_of_importance is None) or (sum_of_number is None):
        print("Provide numbers, degrees of importance, and their sum.")
        return None
    if len(number) != len(degree_of_importance):
        print("Numbers and degrees of importance must have the same length.")
        return None

    weighted_sum = sum(n * w for n, w in zip(number, degree_of_importance))
    return weighted_sum / sum_of_number


@tool
def calculate_minimum_lease_payment(pv: float, p: float, r: float, n: int, rv: float):
    """Calculate the minimum lease payment.

    Args:
        pv: Present value.
        p: Annual lease payments.
        r: Interest rate.
        n: Number of years in the lease term.
        rv: Residual value.

    Returns:
        Minimum lease payment.
    """
    if (pv is None) or (p is None) or (r is None) or (n is None) or (rv is None):
        print("Provide all required parameters (PV, P, r, n, RV).")
        return None

    total_lease_payment = sum(p / ((1 + r) ** i) for i in range(1, n + 1))
    residual_payment = rv / ((1 + r) ** n)
    return total_lease_payment + residual_payment


@tool
def calculate_cash_flow(total_income: float, total_expenses: float):
    """Calculate the cash flow of the company.

    Args:
        total_income: Total income of the company.
        total_expenses: Total expenses of the company.

    Returns:
        Cash flow (Total Income – Total Expenses).
    """
    if (total_income is None) or (total_expenses is None):
        print("Provide both total income and total expenses.")
        return None

    return total_income - total_expenses

# %% [markdown]
# ### 1219 tools

# %%
from typing import Optional, List
@tool
def calculate_net_loss(gross_loss: float, gains: float):
    """Calculate the net loss given gross loss and gains."""
    if gross_loss is None or gains is None:
        return None
    return gross_loss - gains

@tool
def calculate_difference(value1: float, value2: float) -> float:
    """
    Calculate the difference between two numerical values.

    Args:
        value1: The first value.
        value2: The second value.

    Returns:
        The difference between value1 and value2.
    """
    return value1 - value2


@tool
def calculate_average(values: List[float]) -> float:
    """
    Calculate the average of a list of numerical values.

    Args:
        values: A list of numerical values.

    Returns:
        The average of the values.
    """
    return sum(values) / len(values)


@tool
def calculate_sum(values: List[float]) -> float:
    """
    Calculate the sum of a list of numerical values.

    Args:
        values: A list of numerical values.

    Returns:
        The sum of the values.
    """
    return sum(values)

# %% [markdown]
# ### Retriever Tool

# %% [markdown]
# #### Build Vector DB
#
# You can skip this part for demo.

# %%
import json

def load_and_view_sample(file_path):
  """Loads a JSON file and prints a sample of its contents."""
  try:
    with open(file_path, 'r') as f:
      data = json.load(f)
      print("Sample Data from JSON:")
      print(json.dumps(data, indent=2)[:500]) # Print first 500 chars for sample
  except FileNotFoundError:
    print(f"File not found: {file_path}")
  except json.JSONDecodeError:
    print(f"Error decoding JSON from file: {file_path}")


# Assuming your file is named 'test.json' in the current directory
load_and_view_sample('test.json')
# Out:
# Sample Data from JSON:
# [
#   {
#     "pre_text": [
#       "entergy corporation and subsidiaries management 2019s financial discussion and analysis a result of the entergy louisiana and entergy gulf states louisiana business combination , results of operations for 2015 also include two items that occurred in october 2015 : 1 ) a deferred tax asset and resulting net increase in tax basis of approximately $ 334 million and 2 ) a regulatory liability of $ 107 million ( $ 66 million net-of-tax ) as a result of customer credits

# %%
import json

def count_rows_in_json(file_path):
  """Counts the number of rows (objects) in a JSON file."""
  try:
    with open(file_path, 'r') as f:
      data = json.load(f)
      if isinstance(data, list):
        return len(data)
      elif isinstance(data, dict):
        return len(data)
      else:
        return 0  # Or raise an error, depending on your needs
  except FileNotFoundError:
    print(f"File not found: {file_path}")
    return 0
  except json.JSONDecodeError:
    print(f"Error decoding JSON from file: {file_path}")
    return 0

# Assuming your file is named 'test.json' in the current directory
num_rows = count_rows_in_json('test.json')
print(f"Number of rows in the JSON file: {num_rows}")
# Out:
# Number of rows in the JSON file: 1147

# %%
import json

def analyze_json(file_path):
  """Analyzes a JSON file, printing information about its attributes."""
  try:
    with open(file_path, 'r') as f:
      data = json.load(f)
      if isinstance(data, list):
        print("JSON file contains a list of objects.")
        if len(data) > 0:
          print("Example object:")
          print(json.dumps(data[0], indent=2))
          for key in data[0].keys():
            print(f"- Attribute: {key}")
      elif isinstance(data, dict):
        print("JSON file contains a dictionary.")
        print("Attributes:")
        for key in data.keys():
          print(f"- Attribute: {key}")
      else:
        print("JSON file is empty or contains an unexpected data type.")
  except FileNotFoundError:
    print(f"File not found: {file_path}")
  except json.JSONDecodeError:
    print(f"Error decoding JSON from file: {file_path}")

# Analyze 'test.json'
analyze_json('test.json')
# Out:
# JSON file contains a list of objects.
# Example object:
# {
#   "pre_text": [
#     "entergy corporation and subsidiaries management 2019s financial discussion and analysis a result of the entergy louisiana and entergy gulf states louisiana business combination , results of operations for 2015 also include two items that occurred in october 2015 : 1 ) a deferred tax asset and resulting net increase in tax basis of approximately $ 334 million and 2 ) a regulatory liability of $ 107 million ( $ 66 million net-of-tax ) as a result of customer credits to be realized by electric customers of entergy louisiana , consistent with the terms of the stipulated settlement in the business combination proceeding .",
#     "see note 2 to the financial statements for further discussion of the business combination and customer credits .",
#     "results of operations for 2015 also include the sale in december 2015 of the 583 mw rhode island state energy center for a realized gain of $ 154 million ( $ 100 million net-of-tax ) on the sale and the $ 77 million ( $ 47 million net-of-tax ) write-off and regulatory charges to recognize that a portion of the assets associated with the waterford 3 replacement steam generator project is no longer probable of recovery .",
#     "see note 14 to the financial statements for further discussion of the rhode island state energy center sale .",
#     "see note 2 to the financial statements for further discussion of the waterford 3 write-off .",
#     "results of operations for 2014 include $ 154 million ( $ 100 million net-of-tax ) of charges related to vermont yankee primarily resulting from the effects of an updated decommissioning cost study completed in the third quarter 2014 along with reassessment of the assumptions regarding the timing of decommissioning cash flows and severance and employee retention costs .",
#     "see note 14 to the financial statements for further discussion of the charges .",
#     "results of operations for 2014 also include the $ 56.2 million ( $ 36.7 million net-of-tax ) write-off in 2014 of entergy mississippi 2019s regulatory asset associated with new nuclear generation development costs as a result of a joint stipulation entered into with the mississippi public utilities staff , subsequently approved by the mpsc , in which entergy mississippi agreed not to pursue recovery of the costs deferred by an mpsc order in the new nuclear generation docket .",
#     "see note 2 to the financial statements for further discussion of the new nuclear generation development costs and the joint stipulation .",
#     "net revenue utility following is an analysis of the change in net revenue comparing 2015 to 2014 .",
#     "amount ( in millions ) ."
#   ],
#   "post_text": [
#     "the retail electric price variance is primarily due to : 2022 formula rate plan increases at entergy louisiana , as approved by the lpsc , effective december 2014 and january 2015 ; 2022 an increase in energy efficiency rider revenue primarily due to increases in the energy efficiency rider at entergy arkansas , as approved by the apsc , effective july 2015 and july 2014 , and new energy efficiency riders at entergy louisiana and entergy mississippi that began in the fourth quarter 2014 ; and 2022 an annual net rate increase at entergy mississippi of $ 16 million , effective february 2015 , as a result of the mpsc order in the june 2014 rate case .",
#     "see note 2 to the financial statements for a discussion of rate and regulatory proceedings. ."
#   ],
#   "filename": "ETR/2016/page_23.pdf",
#   "table_ori": [
#     [
#       "",
#       "Amount (In Millions)"
#     ],
#     [
#       "2014 net revenue",
#       "$5,735"
#     ],
#     [
#       "Retail electric price",
#       "187"
#     ],
#     [
#       "Volume/weather",
#       "95"
#     ],
#     [
#       "Waterford 3 replacement steam generator provision",
#       "(32)"
#     ],
#     [
#       "MISO deferral",
#       "(35)"
#     ],
#     [
#       "Louisiana business combination customer credits",
#       "(107)"
#     ],
#     [
#       "Other",
#       "(14)"
#     ],
#     [
#       "2015 net revenue",
#       "$5,829"
#     ]
#   ],
#   "table": [
#     [
#       "",
#       "amount ( in millions )"
#     ],
#     [
#       "2014 net revenue",
#       "$ 5735"
#     ],
#     [
#       "retail electric price",
#       "187"
#     ],
#     [
#       "volume/weather",
#       "95"
#     ],
#     [
#       "waterford 3 replacement steam generator provision",
#       "-32 ( 32 )"
#     ],
#     [
#       "miso deferral",
#       "-35 ( 35 )"
#     ],
#     [
#       "louisiana business combination customer credits",
#       "-107 ( 107 )"
#     ],
#     [
#       "other",
#       "-14 ( 14 )"
#     ],
#     [
#       "2015 net revenue",
#       "$ 5829"
#     ]
#   ],
#   "qa": {
#     "question": "what is the net change in net revenue during 2015 for entergy corporation?",
#     "answer": "94",
#     "explanation": "",
#     "ann_table_rows": [
#       1,
#       8
#     ],
#     "ann_text_rows": [],
#     "steps": [
#       {
#         "op": "minus2-1",
#         "arg1": "5829",
#         "arg2": "5735",
#         "res": "94"
#       }
#     ],
#     "program": "subtract(5829, 5735)",
#     "gold_inds": {
#       "table_1": "the 2014 net revenue of amount ( in millions ) is $ 5735 ;",
#       "table_8": "the 2015 net revenue of amount ( in millions ) is $ 5829 ;"
#     },
#     "exe_ans": 94.0,
#     "tfidftopn": {
#       "text_9": "net revenue utility following is an analysis of the change in net revenue comparing 2015 to 2014 ."
#     },
#     "program_re": "subtract(5829, 5735)",
#     "model_input": [
#       [
#         "table_1",
#         "the 2014 net revenue of amount ( in millions ) is $ 5735 ;"
#       ],
#       [
#         "table_3",
#         "the volume/weather of amount ( in millions ) is 95 ;"
#       ],
#       [
#         "table_8",
#         "the 2015 net revenue of amount ( in millions ) is $ 5829 ;"
#       ]
#     ]
#   },
#   "id": "ETR/2016/page_23.pdf-2",
#   "table_retrieved": [
#     {
#       "score": 3.0425944328308105,
#       "ind": "table_8"
#     },
#     {
#       "score": 2.630547046661377,
#       "ind": "table_1"
#     },
#     {
#       "score": 0.7781655788421631,
#       "ind": "table_3"
#     },
#     {
#       "score": 0.606473982334137,
#       "ind": "table_7"
#     }
#   ],
#   "text_retrieved": [
#     {
#       "score": 0.3962186276912689,
#       "ind": "text_10"
#     }
#   ],
#   "table_retrieved_all": [
#     {
#       "score": 3.0425944328308105,
#       "ind": "table_8"
#     },
#     {
#       "score": 2.630547046661377,
#       "ind": "table_1"
#     },
#     {
#       "score": 0.7781655788421631,
#       "ind": "table_3"
#     },
#     {
#       "score": 0.606473982334137,
#       "ind": "table_7"
#     },
#     {
#       "score": 0.3680412769317627,
#       "ind": "table_2"
#     },
#     {
#       "score": -0.06215459108352661,
#       "ind": "table_5"
#     },
#     {
#       "score": -0.23549103736877441,
#       "ind": "table_4"
#     },
#     {
#       "score": -1.1832187175750732,
#       "ind": "table_6"
#     },
#     {
#       "score": -3.0562329292297363,
#       "ind": "table_0"
#     }
#   ],
#   "text_retrieved_all": [
#     {
#       "score": 0.3962186276912689,
#       "ind": "text_10"
#     },
#     {
#       "score": -0.6703973412513733,
#       "ind": "text_0"
#     },
#     {
#       "score": -0.8628821969032288,
#       "ind": "text_11"
#     },
#     {
#       "score": -0.9996260404586792,
#       "ind": "text_9"
#     },
#     {
#       "score": -1.4163694381713867,
#       "ind": "text_2"
#     },
#     {
#       "score": -1.4738928079605103,
#       "ind": "text_7"
#     },
#     {
#       "score": -1.6805188655853271,
#       "ind": "text_5"
#     },
#     {
#       "score": -1.8574978113174438,
#       "ind": "text_12"
#     },
#     {
#       "score": -2.2638840675354004,
#       "ind": "text_6"
#     },
#     {
#       "score": -2.363234519958496,
#       "ind": "text_8"
#     },
#     {
#       "score": -2.428662061691284,
#       "ind": "text_4"
#     },
#     {
#       "score": -2.465285062789917,
#       "ind": "text_1"
#     },
#     {
#       "score": -2.482703924179077,
#       "ind": "text_3"
#     }
#   ]
# }
# - Attribute: pre_text
# - Attribute: post_text
# - Attribute: filename
# - Attribute: table_ori
# - Attribute: table
# - Attribute: qa
# - Attribute: id
# - Attribute: table_retrieved
# - Attribute: text_retrieved
# - Attribute: table_retrieved_all
# - Attribute: text_retrieved_all

# %%
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langchain_core.prompts import PromptTemplate
from pydantic import BaseModel, Field
from langchain_core.output_parsers import StrOutputParser
from datetime import datetime
import json

# Define pre_text and post_text
pre_text = """
## Financial Data Analysis with Tools

This system is designed to analyze financial data and answer your questions about companies.
It uses tools like calculating metrics (EPS, cash flow from operations) and retrieving information from a financial dataset.

"""

post_text = """
**Note:** The system may not always have the information you're looking for.
If the response is insufficient, please refine your question or provide more details.
"""

# Define a table with examples
table = """
| Question Example | Expected Outcome |
|---|---|
| What was Apple's EPS in 2022? | Retrieves Apple's 2022 net income and shares outstanding, then calculates and returns EPS. |
| What was the cash flow from operations for Microsoft in 2023? | Retrieves Microsoft's net income, non-cash items, and changes in working capital, then calculates and returns cash flow from operations. |
"""

# Combine pre_text, post_text, and table
combined_text = f"{pre_text}\n\n**Example Usage:**\n\n{table}\n\n{post_text}"

# Function to ask ChatGPT and compare answers
def qa_and_compare(question):
    prompt_with_context = f"{combined_text}\n\n**Question:** {question}"

    messages = [HumanMessage(content=prompt_with_context)]

    ai_msg = llm.invoke(messages)

    print("ChatGPT's Answer:")
    print(ai_msg.content)


# Example question
question = "What was the revenue of Apple in 2022?"

qa_and_compare(question)
# Out:
# ChatGPT's Answer:
# To provide you with the revenue of Apple in 2022, I would need to retrieve the relevant financial data. However, I currently do not have access to real-time financial datasets.
#
# As of my last update, Apple's revenue for the fiscal year 2022 was approximately $394.3 billion. For the most accurate and up-to-date information, please refer to Apple's official financial statements or a reliable financial news source.

# %%
with open('test.json', 'r') as f:
    train_data = json.load(f)

# Generate distinct_items_with_context
distinct_items_with_context = {}

for item in train_data:
    filename = item['filename']

    distinct_items_with_context[filename] = {
        'pre_text': item.get('pre_text', []),
        'post_text': item.get('post_text', []),
        'table': item.get('table', [])
    }

#Check the generated dictionary
print(f"Generated distinct_items_with_context with {len(distinct_items_with_context)} items.")

def merge_text_list(text_list):
    """Merge a list of strings into a single string with newline separation."""
    if not isinstance(text_list, list):
        raise ValueError("Input must be a list of strings.")
    return "\n".join(text_list)
# Out:
# Generated distinct_items_with_context with 380 items.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from tqdm import tqdm  # Import tqdm for progress tracking

# Initialize text splitter and embeddings
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
embeddings = OpenAIEmbeddings(model='text-embedding-3-small', api_key=OPENAI_API_KEY)

# Function to process context data and save it into Chroma vector DB
def save_to_chroma(distinct_items_with_context, persist_directory="./db_test"):
    """
    Saves processed text data and metadata into a Chroma vector database.

    Args:
        distinct_items_with_context (dict): Dictionary containing context data with keys 'pre_text', 'post_text', and 'table'.
        persist_directory (str): Directory to save the vector database.
    """
    all_texts = []
    all_metadatas = []

    # Iterate through each file and process its context
    for filename, context_data in tqdm(distinct_items_with_context.items(), desc="Processing files"):
        # Extract ticker and fiscal year from filename or context_data (custom logic)
        ticker = filename.split('/')[0]  
        fiscal = filename.split('/')[1]  

        # Merge and split pre-text and post-text
        pre_text = merge_text_list(context_data.get('pre_text', []))
        post_text = merge_text_list(context_data.get('post_text', []))
        table = "\n".join([" | ".join(row) for row in context_data.get('table', [])])

        pre_text_chunks = splitter.split_text(pre_text)
        post_text_chunks = splitter.split_text(post_text)

        # Collect texts and corresponding metadata
        texts_for_db = pre_text_chunks + ([table] if table.strip() else []) + post_text_chunks
        metadatas_for_db = (
            [{'filename': filename, 'context_type': 'pre_text', 'company': ticker, 'fiscal': fiscal}] * len(pre_text_chunks) +
            ([{'filename': filename, 'context_type': 'table', 'company': ticker, 'fiscal': fiscal}] if table.strip() else []) +
            [{'filename': filename, 'context_type': 'post_text', 'company': ticker, 'fiscal': fiscal}] * len(post_text_chunks)
        )

        all_texts.extend(texts_for_db)
        all_metadatas.extend(metadatas_for_db)

    # Create and persist the vector database
    print(f"Saving {len(all_texts)} documents to Chroma DB...")
    docsearch = Chroma.from_texts(
        all_texts,
        embeddings,
        metadatas=all_metadatas,
        persist_directory=persist_directory
    )

    docsearch.persist()
    print("Chroma DB successfully persisted!")

# Example usage
# Assuming 'distinct_items_with_context' is already defined
save_to_chroma(distinct_items_with_context)
# Out:
# Processing files: 100%|██████████| 380/380 [00:00<00:00, 11280.12it/s]
# Saving 4044 documents to Chroma DB...
# Chroma DB successfully persisted!

# %% [markdown]
# #### Load Vector DB

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
import re
import json
from typing import Dict, List, Optional, Any

embeddings = OpenAIEmbeddings(model='text-embedding-3-small',api_key=OPENAI_API_KEY)

from langchain_chroma import Chroma

docsearch = Chroma(
    persist_directory="./test_db",
    embedding_function=embeddings
)

# %% [markdown]
# #### Retriever tool with filtered search

# %%
def retrieve(question:str, ticker: str, fy: int) -> list[str]:
  """Search vector DB for the financial reports with the question and ticker and fiscal year

   Args:
        question: Question need to be answered
        ticker: Ticker of the company for filtering the documents
        fy: Fiscal year for filtering the documents

    Returns:
        A related document for the question.
  """
  retriever = docsearch.as_retriever(search_kwargs={'k': 10, 'filter':
  {
      "$and": [
          {
              "company": {
                  "$eq": ticker
              }
          },
          {
              "fiscal": {
                  "$eq": fy
              }
          }
      ]
  }})

  retriever = docsearch.as_retriever(search_kwargs={"k": 1})
  result = retriever.invoke(question)
  print("Result without filters:", result)


  result = retriever.invoke(question)
  if result:
    return result
  else:
    return ["No data returned. Try again with correct ticker and fiscal year, or different question"]

# %%
# Check stored data
documents = docsearch.get()['documents']
metadatas = docsearch.get()['metadatas']

print(f"Number of documents in the DB: {len(documents)}")
print("Sample metadata:", metadatas[:5])  # Print metadata of the first 5 documents
# Out:
# Number of documents in the DB: 2089
# Sample metadata: [{'company': 'ETR', 'context_type': 'pre_text', 'fiscal': 2016}, {'company': 'ETR', 'context_type': 'pre_text', 'fiscal': 2016}, {'company': 'ETR', 'context_type': 'pre_text', 'fiscal': 2016}, {'company': 'ETR', 'context_type': 'table', 'fiscal': 2016}, {'company': 'ETR', 'context_type': 'post_text', 'fiscal': 2016}]

# %%
retrieve("what was the hqla in the q4 of Citigroup in 2015?","C", 2015)
# Out:
# Result without filters: [Document(metadata={'company': 'C', 'context_type': 'table', 'fiscal': 2015}, page_content='in billions of dollars,dec . 31 2015,sept . 30 2015,dec . 31 2014\r\nhqla,$ 378.5,$ 398.9,$ 412.6\r\nnet outflows,336.5,355.6,368.6\r\nlcr,112% ( 112 % ),112% ( 112 % ),112% ( 112 % )\r\nhqla in excess of net outflows,$ 42.0,$ 43.3,$ 44.0\r\n')]
# [Document(metadata={'company': 'C', 'context_type': 'table', 'fiscal': 2015}, page_content='in billions of dollars,dec . 31 2015,sept . 30 2015,dec . 31 2014\r\nhqla,$ 378.5,$ 398.9,$ 412.6\r\nnet outflows,336.5,355.6,368.6\r\nlcr,112% ( 112 % ),112% ( 112 % ),112% ( 112 % )\r\nhqla in excess of net outflows,$ 42.0,$ 43.3,$ 44.0\r\n')]

# %%
@tool
def retrieve_factual_data(question: str, ticker: str, fy: int) -> List[str]:
    """
    Retrieve relevant documents from the vector database based on the question, company ticker, and fiscal year.

    Args:
        question: The financial question from the user.
        ticker: The company ticker used to filter the documents.
        fy: The fiscal year used to filter the documents.

    Returns:
        A list of strings, where each string is the content of a relevant document.
        If no documents are found, returns a message indicating no data was found.
    """
    retriever = docsearch.as_retriever(search_kwargs={'k': 10})
    results = retriever.invoke(question)
    if not results:
        return ["No relevant documents found."]
    return [result.page_content for result in results]



def extract_key_terms(question: str) -> List[str]:
    """
    Extract key terms from the question to validate relevance.
    
    Args:
        question: The user's question.
    
    Returns:
        A list of key terms from the question.
    """
    terms = [word.strip(".,?") for word in question.split()]
    return [term for term in terms if len(term) > 2]  # Filter out short or non-informative terms

# %%
@tool
def retrieve_financial_data_tool(query: str) -> str:
    """
    Retrieve financial data for a given query, integrating tools for fiscal year and ticker extraction.

    Args:
        query: User's financial question.

    Returns:
        Relevant financial data or an informative message.
    """
    try:
        # Extract ticker and fiscal year
        ticker, fiscal_year = rewrite2fiscal(query)

        if not ticker or not fiscal_year:
            return "Error: Unable to determine company or fiscal year from the query."

        # Retrieve relevant financial data
        result = retrieve_factual_data.invoke({
            "question": query,
            "ticker": ticker,
            "fy": fiscal_year
        })

        if "Error" in result or "No data" in result:
            return (
                f"Could not find relevant data for {ticker} in fiscal year {fiscal_year}. "
                "Please refine your query or check the company name and fiscal year."
            )

        # Format result for better readability
        formatted_result = (
            # f"**Query:** {query}\n"
            # f"**Company (Ticker):** {ticker}\n"
            # f"**Fiscal Year:** {fiscal_year}\n"
            f"**Retrieved Data:**\n{result.strip()}"
        )

        return formatted_result

    except Exception as e:
        return f"Error during retrieval: {str(e)}"
    
def combine_documents(documents: List[str]) -> str:
    """
    Combine multiple documents into a single string for processing.
    """
    return "\n\n".join(documents)

# %%
from typing import Dict, List, Optional, Any

def extract_value_from_docs(documents: List[str], key: str) -> Optional[float]:
    """
    Extract a numerical value corresponding to a specific key from the documents.

    Args:
        documents: A list of retrieved documents.
        key: The key to search for in the documents.

    Returns:
        The extracted numerical value as a float, or None if the value is not found.
    """
    for doc in documents:
        if key.lower() in doc.lower():
            # Extract the numerical value (assuming it appears after the key)
            match = re.search(rf"{key}\s*[:\-]?\s*(\d+(\.\d+)?)", doc, re.IGNORECASE)
            if match:
                return float(match.group(1))
    return None

def extract_tool_inputs(tool_name: str, documents: List[str]) -> Dict[str, Any]:
    """
    Extract required inputs for a specific tool from the retrieved documents.

    Args:
        tool_name: The name of the tool.
        documents: A list of retrieved documents.

    Returns:
        A dictionary of extracted inputs for the tool, or an empty dictionary if no relevant data is found.
    """
    tool_inputs = {}

    # Example: Extract inputs for calculate_interest_income
    if tool_name == "calculate_interest_income":
        tool_inputs["average_cash_and_cash_equivalents"] = extract_value_from_docs(documents, "average cash")
        tool_inputs["cash_rate"] = extract_value_from_docs(documents, "interest rate")

    # Additional logic for other tools can be added here
    return tool_inputs

# %%
from langchain.tools import Tool
from langchain_core.messages import HumanMessage, SystemMessage

def calculate_financial_ratio_tool(company: str, year: str, ratio_type: str) -> str:  
    try:  
        if ratio_type == "current_ratio":  
            current_assets = retrieve_financial_data_tool(f"current assets {company} {year}")  
            current_liabilities = retrieve_financial_data_tool(f"current liabilities {company} {year}")  
            return float(current_assets) / float(current_liabilities)  
        elif ratio_type == "operating_margin":  
            operating_income = retrieve_financial_data_tool(f"operating income {company} {year}")  
            revenue = retrieve_financial_data_tool(f"revenue {company} {year}")  
            return (float(operating_income) / float(revenue)) * 100  
    except Exception as e:  
        return f"Error calculating ratio: {str(e)}"  

def perform_math_operations_tool(operation: str, values: list) -> str:  
    try:  
        values = [float(v) for v in values]  
        if operation == "difference":  
            return values[0] - values[1]  
        elif operation == "average":  
            return sum(values) / len(values)  
        elif operation == "sum":  
            return sum(values)  
        elif operation == "multiply":  
            result = 1  
            for v in values:  
                result *= v  
            return result  
    except Exception as e:  
        return f"Error in calculation: {str(e)}"  
tools = [
    Tool(
        name="retrieve_financial_data",
        func=retrieve_financial_data_tool,
        description="Retrieve basic financial data for a company."
    ),
    Tool(
        name="calculate_financial_ratio",
        func=calculate_financial_ratio_tool,
        description="Calculate financial ratios like current ratio or operating margin."
    ),
    Tool(
        name="perform_math_operations",
        func=perform_math_operations_tool,
        description="Perform mathematical operations on financial data."
    ),
    Tool(
        name="calculate_operating_profit_margin",
        func=calculate_operating_profit_margin,
        description="Calculate the operating profit margin of the company."
    ),
    Tool(
        name="calculate_revenue",
        func=calculate_revenue,
        description="Calculate revenue based on sales data and average operating revenues."
    ),
    Tool(
        name="calculate_ebt",
        func=calculate_ebt,
        description="Calculate the EBT (Earnings Before Taxes) of the company."
    ),
    Tool(
        name="calculate_ebit",
        func=calculate_ebit,
        description="Calculate the EBIT (Earnings Before Interest and Taxes) of the company."
    ),
    Tool(
        name="calculate_interest_expenses",
        func=calculate_interest_expenses,
        description="Calculate the interest expenses using EBIT and EBT."
    ),
    Tool(
        name="calculate_interest_income",
        func=calculate_interest_income,
        description="Calculate interest income based on average cash equivalents and interest rate."
    ),
    Tool(
        name="calculate_supplementary_leverage_ratio",
        func=calculate_supplementary_leverage_ratio,
        description="Calculate the supplementary leverage ratio of the company."
    ),
    Tool(
        name="calculate_weighted_average",
        func=calculate_weighted_average,
        description="Calculate the weighted average of a dataset based on weights."
    ),
    Tool(
        name="calculate_minimum_lease_payment",
        func=calculate_minimum_lease_payment,
        description="Calculate the minimum lease payment considering lease terms and residual value."
    ),
    Tool(
        name="calculate_cash_flow",
        func=calculate_cash_flow,
        description="Calculate the cash flow of the company based on total income and expenses."
    ),
    Tool(
        name="calculate_net_loss",
        func=calculate_net_loss,
        description="Calculate the net loss given gross loss and gains."
    ),
    Tool(
        name="calculate_difference",
        func=calculate_difference,
        description="Calculate the difference between two numerical values."
    ),
    Tool(
        name="calculate_average",
        func=calculate_average,
        description="Calculate the average of a list of numerical values."
    ),
    Tool(
        name="calculate_sum",
        func=calculate_sum,
        description="Calculate the sum of a list of numerical values."
    ),
    Tool(
        name="extract_key_terms",
        func=extract_key_terms,
        description="Extract key terms from a question to determine relevant tools."
    )
]

# %%
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI

response_prompt = PromptTemplate(
    input_variables=["query", "data"],
    template="""
    You are a financial analysis expert. Your goal is to provide structured answers to financial questions.

    Question: {query}
    Relevant Data: {data}

    Response Format:
    - Answer: [Provide a specific numerical value or clear conclusion.]
    - Reasoning: [Explain how the answer was derived, including calculations or decisions made.]
    - Tools Used: [List the tools used, their inputs, and outputs.]
    """
)

# Function to generate a response
def generate_response(query: str, data: str) -> str:
    """
    Generates a structured response to a financial query using LLM.

    Args:
        query (str): The financial question.
        data (str): Relevant data for answering the query.

    Returns:
        str: A structured response including an answer and reasoning.
    """
    # Format the prompt
    prompt = response_prompt.format(query=query, data=data)

    # Invoke the LLM directly
    response = llm(prompt)

    return response

# %% [markdown]
# ## Agent with tools

# %%
def tool_selector(keywords: List[str]) -> List[str]:
    """
    Map keywords to relevant tools.
    """
    tool_mapping = {
        "current ratio": ["calculate_current_ratio"],
        "operating profit margin": ["calculate_operating_profit_margin"],
        "revenue": ["retrieve_financial_data_tool", "calculate_revenue"],
        "cashflow": ["retrieve_financial_data_tool"],
        "lease payment": ["calculate_minimum_lease_payment"],
        "interest": ["calculate_interest_expenses", "calculate_interest_income"],
    }
    selected_tools = []
    for keyword in keywords:
        selected_tools.extend(tool_mapping.get(keyword, []))
    return list(set(selected_tools))  # Remove duplicates

def agentic_rag(query: str) -> str:
    # Step 1: Extract keywords
    keywords = extract_key_terms(query)  

    # Step 2: Select relevant tools
    tools_to_use = tool_selector(keywords)

    # Step 3: Extract ticker and fiscal year
    ticker, fy = rewrite2fiscal(query)  
    if not ticker or not fy:
        return "Error: Unable to determine company or fiscal year from the query."

    # Step 4: Retrieve documents and combine them
    documents = retrieve_factual_data.invoke({"question": query, "ticker": ticker, "fy": fy})
    combined_data = combine_documents(documents)

    # Step 5: Use selected tools (if any) to enrich data
    tool_responses = []
    for tool in tools_to_use:
        if tool in globals():
            # Extract the required parameters for the tool
            tool_inputs = extract_tool_inputs(tool, documents)

            if tool_inputs:  # Ensure that parameters are available
                try:
                    tool_response = globals()[tool](**tool_inputs)
                    tool_responses.append(tool_response)
                except Exception as e:
                    print(f"Error calling tool {tool}: {e}")
            else:
                print(f"No inputs found for tool {tool}. Skipping...")


    # Step 6: Generate structured response
    enriched_data = combined_data + "\n\n" + "\n\n".join(tool_responses)
    structured_response = generate_response(query, enriched_data)
    return structured_response

# %% [markdown]
# ## Scoring section
#
# Use this Q&A dictionary to test your project code.
#
# You should not change the scoring prompt.
#
# You can submit your accuracy result with the screenshot to TA email, then I will post the score to the leaderboard.

# %%
qa_dict = [{'Question': '"what was the hqla in the q4 of Citigroup in 2015"',
  'Answer': '"378.5 billion dollars"'},
 {'Question': '"as a result of the sales of certain non-core towers and other assets what was the recorded net losses of American Tower in 2008"',
  'Answer': '"10.5 million dollars"'},
 {'Question': '"what was the port call costsin of Royal Caribbean Cruises in 2012"',
  'Answer': '"459.8 million dollars"'},
 {'Question': '"what is the aggregate rent expense of American Tower Corp in 2014?"',
  'Answer': '"655.0 million dollars"'},
 {'Question': '"what is the long-term component of BlackRock at 12/31/2011?"',
  'Answer': '"593356 million dollars"'},
 {'Question': '"at december 31 , 2012 of The PNC Financial Services, what was the potential maximum exposure under the loss share arrangements?"',
  'Answer': '"3.9 billion dollars"'},
 {'Question': '"what is the total financial liabilities at fair value of Goldman Sachs in 2012?"',
  'Answer': '"377677 million dollars"'},
 {'Question': '"what was brazilian paper sales of International Paper Company in 2006?"',
  'Answer': '"496 million dollars"'},
 {'Question': '"what was brazilian paper sales of International Paper Company in 2005?"',
  'Answer': '"465 million dollars"'},
 {'Question': '"what is the cashflow of Kellogg in 2006?"',
  'Answer': '"957.4 million dollars"'},
 {'Question': '"From the perspective of 5 years ago, what percentage of total minimum lease payments of Dish Network are due in 2015?"',
  'Answer': '"9.772%"'},
 {'Question': '"in 2011 what was the SL Green Realty Corp\'s percent of the change in the account balance at end of year"',
  'Answer': '"6.75%"'},
 {'Question': '"what was the value in thousands of unvested restricted stock and performance awards at the weighted-averagegrant-datefair value as of december 31 , 2018 of Global Payments?"',
  'Answer': '"117624.84"'},
 {'Question': '"based on the cash dividends paid of the year, how many common stock shares were outstanding in 2007 Snap-on?"',
  'Answer': '"58909091"'},
 {'Question': '"what is the Entergy Corp\'s 2008 total value , in millions of dollars , of issuable long-term securities?"',
  'Answer': '"1450"'},
 {'Question': '"for the capital framework of Goldman Sachs Group 7 years ago, what percent of the minimum supplementary leverage ratio consisted of a buffer?"',
  'Answer': '"40%"'},
 {'Question': '"in 2007 what was the 3M\'s ratio of the interest expense to the interest income"',
  'Answer': '"1.59"'},
 {'Question': '"what is the AON\'s decrease observed in the additions for tax positions of prior years as of 2018, in millions?"',
  'Answer': '"2"'},
 {'Question': '"In 2014 Global Payments, what is the total value of securities approved by security holders but net yer issued , ( in millions ) ?"',
  'Answer': '"365.4"'},
 {'Question': '"what is the percent of our network route miles that is owned rather than operated on pursuant to trackage rights or leases in 2016 Union Pacific Corp"',
  'Answer': '"81.2%"'},
 {'Question': '"What is the American Tower Corp\'s current ratio in 12 years ago?"',
  'Answer': 1.7923},
 {'Question': '"What is the DISH Network Corporation\'s current ratio in 13 years ago?"',
  'Answer': 1.7804},
 {'Question': '"What is the American Tower Corp\'s current ratio in 2012?"',
  'Answer': 1.7923},
 {'Question': '"What is the DISH Network Corporation\'s current ratio in 2011?"',
  'Answer': 1.7804},
 {'Question': '"What is the International Paper Company\'s Operating Profit Margin in 2006?"',
  'Answer': 9.769119769},
 {'Question': '"What is the International Paper Company\'s Operating Profit Margin in 2005?"',
  'Answer': 6.59693166},
 {'Question': '"What is the International Paper Company\'s Operating Profit Margin in 2004?"',
  'Answer': 7.119831815},
 {'Question': '"What is the Air Products and Chemicals\'s Operating Profit Margin in 2016?"',
  'Answer': 26.7735375},
 {'Question': '"What is the Air Products and Chemicals\'s Operating Profit Margin in 2015?"',
  'Answer': 21.88472888},
 {'Question': '"What is the Air Products and Chemicals\'s Operating Profit Margin in 2014?"',
  'Answer': 18.69805075},
 {'Question': '"What is the difference of Operating Profit Margin between Air Products and Chemicals in 2016 and International Paper Company in 2006?"',
  'Answer': '17.00441774'},
 {'Question': '"What is the average of Operating Profit Margin between Air Products and Chemicals in 2016 and International Paper Company in 2005?"',
  'Answer': '16.68523458'},
 {'Question': '"What is the sum of Operating Profit Margin between Air Products and Chemicals in 2016 and International Paper Company in 2004?"',
  'Answer': '33.89336932'},
 {'Question': '"Which one\'s Operating Profit Margin is bigger between Air Products and Chemicals in 2014 and International Paper Company in 2006?"',
  'Answer': 'Air Products and Chemicals'},
 {'Question': '"What is the difference of Operating Profit Margin between Air Products and Chemicals in 2015 and International Paper Company in 2006?"',
  'Answer': '12.11560911'},
 {'Question': '"What is the average of Operating Profit Margin between Air Products and Chemicals in 2015 and International Paper Company in 2005?"',
  'Answer': '14.24083027'},
 {'Question': '"What is the sum of Operating Profit Margin between Air Products and Chemicals in 2015 and International Paper Company in 2004?"',
  'Answer': '29.00456069'},
 {'Question': '"Which one\'s current ratio is bigger between American Tower Corp in 2012 and DISH Network Corporation in 2011?"',
  'Answer': 'American Tower Corp'},
 {'Question': '"What is the average of current ratio between American Tower Corp in 2012 and DISH Network Corporation in 2011?"',
  'Answer': '1.786341177'},
 {'Question': '"What is the difference of current ratio between American Tower Corp in 2012 and DISH Network Corporation in a year before that?"',
  'Answer': '0.01185521735'},
 {'Question': '"What is the Goldman Sachs Group\'s Total Assets change from 2014 to 2016 multiplied by the average of current ratio between American Tower Corp in 2012 and DISH Network Corporation in 2011?"',
  'Answer': '48722.45 million'},
 {'Question': '"What is the Goldman Sachs Group\'s Total Assets change from 2013 to 2017 multiplied by the average of current ratio between American Tower Corp in 2012 and DISH Network Corporation in 2011?"',
  'Answer': '46296.6 million'},
 {'Question': '"What is the sum of Goldman Sachs Group\'s Total Assets from 2011 to 2014 divided by the average of Operating Profit Margin between Air Products and Chemicals in 2016 and International Paper Company in 2005?',
  'Answer': '217529.28 million'},
 {'Question': '"What is the sum of Goldman Sachs Group\'s Total Assets from 2011 to 2014 multiplied by the average of Operating Profit Margin between Air Products and Chemicals in 2015 and International Paper Company in 2005?"',
  'Answer': '51687477.96 million'},
 {'Question': '"What is the Goldman Sachs Group\'s Total Assets change from 2014 to 2016 divided the difference of Operating Profit Margin between Air Products and Chemicals in 2016 and International Paper Company in 2006?"',
  'Answer': '1604 million'},
 {'Question': '"What is the Goldman Sachs Group\'s Total Assets change from 2013 to 2017 dividied the sum of Operating Profit Margin between Air Products and Chemicals in 2016 and International Paper Company in 2004?"',
  'Answer': '764.6 million'},
 {'Question': '"What is the difference of Union Pacific Corp\'s revenue from 2013 to 2016 divided the sum of Operating Profit Margin between Air Products and Chemicals in 2015 and International Paper Company in 2004?"',
  'Answer': '-69.7 million'},
 {'Question': '"What is the average of Union Pacific Corp\'s revenue from 2013 to 2016 divided by the sum of Operating Profit Margin between Air Products and Chemicals in 2015 and International Paper Company in 2004?"',
  'Answer': '755.95 million'},
 {'Question': '"What is the difference of Union Pacific Corp\'s revenue from 2013 to 2016 multiplied by the average of current ratio between American Tower Corp in 2012 and DISH Network Corporation in 2011?"',
  'Answer': '-3611.98 million'},
 {'Question': '"What is the average of Union Pacific Corp\'s revenue from 2013 to 2016 divided by the average of Operating Profit Margin between Air Products and Chemicals in 2015 and International Paper Company in 2005?"',
  'Answer': '1539.67 million'}]

# %%
score_answer_prompt = PromptTemplate(
    input_variables=["question", "answer", "response"],
    template="""
    You have to score the response by comparing with the answer.
    You should score 0 or 1 as JSON with "score" key.
    You can ignore minor difference with the unit or numerical value.
    Question: {question}
    Answer: {answer}
    Response: {response}
    Score:

    Output JSON: {{
      "score": 1 if the answer response is meaningfully the same as the answer, 0 if the response is different from the answer>
    }}
    """
)

from pydantic import BaseModel, Field

class Score(BaseModel):
    """Score of the response"""
    score: int = Field(description="score of the response")

score_answer_chain = score_answer_prompt | llm.with_structured_output(Score)

# %%
score_answer_chain.invoke({'question': qa_dict[0]['Question'], 'answer': qa_dict[0]['Answer'], 'response': 'it is 375 B'}).score
# Out:
# 1

# %% [markdown]
# ### Accuracy score

# %%
# Initialize variables
results = []
correct = 0

# Iterate over all questions in the dataset
for i, item in enumerate(qa_dict):
    # Generate model's response
    response = agentic_rag(item['Question'])

    # Extract content if the response has a 'content' attribute
    if hasattr(response, 'content'):
        response = response.content
    print(response)
    
    # Compute the score for the response
    score = score_answer_chain.invoke({
        'question': item['Question'],
        'answer': item['Answer'],
        'response': response
    }).score
    correct += score

    # Record the result for each question
    result = {
        "index": i,  
        "question": item['Question'],  
        "model_answer": response,  
        "correct_answer": item['Answer'],  
        "score": score  
    }
    results.append(result)

    print(i, correct)

# Calculate overall accuracy
accuracy = correct / len(qa_dict)
print(f"Accuracy: {correct}/{len(qa_dict)}")

def serialize_results(results):
    """
    Convert non-JSON serializable objects into serializable ones.
    """
    if isinstance(results, list):
        return [serialize_results(item) for item in results]
    elif isinstance(results, dict):
        return {key: serialize_results(value) for key, value in results.items()}
    elif hasattr(results, 'content'):  
        return results.content
    else:
        return results  

serializable_results = serialize_results(results)

output_file = "1219results.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(serializable_results, f, ensure_ascii=False, indent=4)

print(f"Results saved to {output_file}")
# Out:
# - Answer: The High-Quality Liquid Assets (HQLA) for Citigroup in Q4 of 2015 was $378.5 billion.
#
# - Reasoning: The relevant data provided indicates that the HQLA for Citigroup as of December 31, 2015, was $378.5 billion. This figure is directly taken from the data set provided, which lists HQLA values for different dates, including September 30, 2015, and December 31, 2014, for comparison.
#
# - Tools Used:
#   - Data extraction from the provided financial data table.
#   - No calculations were necessary as the answer was directly available from the data.
# 0 1
# - Answer: The recorded net losses of American Tower in 2008 due to the sales of certain non-core towers and other assets were approximately $10.5 million.
#
# - Reasoning: The relevant data indicates that during the year ended December 31, 2008, American Tower recorded net losses from asset sales and other impairments totaling $10.7 million, which was offset by gains from asset sales of $0.2 million. Therefore, the net loss attributable to these activities is calculated as follows:
#   \[
#   \text{Net Loss} = \text{Net Loss from Asset Sales and Impairments} - \text{Gains from Asset Sales} = 10.7 \text{ million} - 0.2 \text{ million} = 10.5 \text{ million}
#   \]
#
# - Tools Used:
#   - Data extraction from the provided financial statements.
#   - Basic arithmetic calculations to derive the net loss from the given figures.
# 1 2
# - Answer: The port call costs for Royal Caribbean Cruises in 2012 were $459.8 million.
#
# - Reasoning: The relevant data indicates that the amounts of port costs included in passenger ticket revenues on a gross basis for the year 2012 were specifically stated as $459.8 million. This figure represents the direct costs associated with port calls that vary with guest head counts, which are included in the overall revenues and expenses of the company.
#
# - Tools Used:
#   - Financial Statements: The information was derived from the consolidated financial statements and notes provided for the year ending December 31, 2012.
#   - Data Extraction: The specific figure was extracted from the section detailing revenues and expenses, particularly focusing on the port costs mentioned.
# 2 3
# - Answer: The aggregate rent expense of American Tower Corp in 2014 was $309 million.
#
# - Reasoning: The relevant data provided indicates that the rent charged to operating expense for American Tower Corp was specifically stated as $309 million for the year 2014. This figure directly answers the question regarding the aggregate rent expense for that year.
#
# - Tools Used:
#   - Source Document: American Tower Corporation and subsidiaries notes to consolidated financial statements for 2014.
#   - Input: Rent expense data for 2014.
#   - Output: Aggregate rent expense figure of $309 million.
# 3 3
# - Answer: The long-term component of BlackRock at 12/31/2011 is $593,356 million.
#
# - Reasoning: The long-term component is derived from the "long-term" category in the provided data for BlackRock as of December 31, 2011. The relevant data indicates that the long-term assets amount to $593,356 million. This figure is explicitly stated in the data provided for the year ended December 31, 2011.
#
# - Tools Used:
#   - Data extraction from the provided financial statements.
#   - Identification of the relevant line item labeled "long-term" for the specified date.
# 4 4
# - Answer: The potential maximum exposure under the loss share arrangements for The PNC Financial Services at December 31, 2012, is not explicitly stated in the provided data. However, it can be inferred that the exposure is related to the ongoing obligations and commitments associated with the judgment and loss sharing agreements with Visa and other banks.
#
# - Reasoning: The relevant information indicates that PNC has obligations to indemnify Visa for judgments and settlements related to specified litigation, which suggests potential exposure. However, the specific numerical value for maximum exposure under loss share arrangements at December 31, 2012, is not provided in the data. The only related figure mentioned is the $150 million funded into the litigation escrow account by Visa in July 2012, but this does not directly translate to PNC's maximum exposure. Therefore, without additional specific figures or context, a precise numerical value cannot be determined.
#
# - Tools Used: The analysis was conducted using the provided financial data and notes from the PNC Financial Services Group's 2013 Form 10-K. The inputs included various financial figures related to loans, securities, and commitments, while the output was a qualitative assessment of potential exposure based on the available information.
# 5 4
# - Answer: The total financial liabilities at fair value of Goldman Sachs in 2012 was $377,677 million.
#
# - Reasoning: The relevant data from Goldman Sachs' 2012 annual report indicates that the total financial liabilities at fair value as of December 2012 is explicitly stated as $377,677 million. This figure includes all levels of financial liabilities (Level 1, Level 2, and Level 3) after accounting for cash collateral and counterparty netting.
#
# - Tools Used:
#   - Data Source: Goldman Sachs 2012 Annual Report.
#   - Input: Total financial liabilities at fair value as of December 2012: $377,677 million.
#   - Output: Total financial liabilities at fair value = $377,677 million.
# 6 5
# - Answer: Brazilian paper net sales for International Paper Company in 2006 were $496 million.
#
# - Reasoning: The relevant data explicitly states that "brazilian paper net sales for 2006 of $ 496 million were higher than the $ 465 million in 2005 and the $ 417 million in 2004." This information directly provides the sales figure for Brazilian paper in 2006 without the need for further calculations.
#
# - Tools Used:
#   - Textual analysis of the provided data to extract specific financial figures.
#   - No calculations were necessary as the answer was directly stated in the text.
# 7 6
# - Answer: The Brazilian paper sales of International Paper Company in 2005 were $465 million.
#
# - Reasoning: The relevant data states that Brazilian paper net sales for 2006 were $496 million, which was an increase from $465 million in 2005. Therefore, by directly referencing the provided information, we can conclude that the sales figure for 2005 is $465 million.
#
# - Tools Used:
#   - Textual analysis of the provided data to extract specific sales figures.
#   - Logical reasoning to interpret the relationship between the sales figures for 2005 and 2006.
# 8 7
# No inputs found for tool retrieve_financial_data_tool. Skipping...
# - Answer: The cash flow of Kellogg in 2006 was $957.4 million.
#
# - Reasoning: The cash flow is defined as net cash provided by operating activities minus expenditures for property additions. In 2006, Kellogg reported net cash provided by operating activities of $1410.5 million and additions to properties of $453.1 million. Therefore, the cash flow can be calculated as follows:
#
#   \[
#   \text{Cash Flow} = \text{Net Cash Provided by Operating Activities} - \text{Additions to Properties}
#   \]
#   \[
#   \text{Cash Flow} = 1410.5 - 453.1 = 957.4 \text{ million}
#   \]
#
# - Tools Used:
#   - Data from the financial statements of Kellogg for 2006.
#   - Basic arithmetic calculations to derive the cash flow from the provided figures.
# 9 8
# - Answer: 9.76%
#
# - Reasoning: To determine the percentage of total minimum lease payments due in 2015 from the total minimum lease payments, we first need to identify the minimum lease payments due in 2015 and the total minimum lease payments.
#
# From the provided data, the minimum lease payments due in 2015 are $75,970,000 (from the capital lease obligations). The total minimum lease payments are $777,443,000.
#
# To calculate the percentage of the total minimum lease payments due in 2015, we use the formula:
#
# \[
# \text{Percentage} = \left( \frac{\text{Minimum Lease Payments in 2015}}{\text{Total Minimum Lease Payments}} \right) \times 100
# \]
#
# Substituting the values:
#
# \[
# \text{Percentage} = \left( \frac{75,970}{777,443} \right) \times 100 \approx 9.76\%
# \]
#
# - Tools Used:
#   - Basic arithmetic calculations.
#   - Formula for percentage calculation.
#   - Inputs: Minimum lease payments in 2015 ($75,970,000) and total minimum lease payments ($777,443,000).
#   - Output: Percentage of total minimum lease payments due in 2015 (9.76%).
# 10 9
# - Answer: The percent change in the account balance at the end of the year for SL Green Realty Corp in 2011 was approximately -4.9%.
#
# - Reasoning:
#   1. The balance at the end of 2010 was $50.9 million.
#   2. The balance at the end of 2011 was $48.1 million.
#   3. To calculate the percent change, we use the formula:
#      \[
#      \text{Percent Change} = \left( \frac{\text{New Value} - \text{Old Value}}{\text{Old Value}} \right) \times 100
#      \]
#   4. Plugging in the values:
#      \[
#      \text{Percent Change} = \left( \frac{48.1 - 50.9}{50.9} \right) \times 100 = \left( \frac{-2.8}{50.9} \right) \times 100 \approx -5.5\%
#      \]
#   5. Rounding to one decimal place gives approximately -4.9%.
#
# - Tools Used:
#   - Basic arithmetic calculations for percent change.
#   - Data extraction from the provided financial statements for the years 2010 and 2011.
# 11 9
# - Answer: The value of unvested restricted stock and performance awards at the weighted-average grant-date fair value as of December 31, 2018, for Global Payments is $1,818,000 (in thousands).
#
# - Reasoning:
#   To calculate the total value of unvested restricted stock and performance awards as of December 31, 2018, we need to consider the unvested shares and their respective weighted-average grant-date fair values.
#
# 1. **Unvested Performance Share Awards**:
#    - Unvested at December 31, 2018: 31,728,596 shares
#    - Weighted-average grant-date fair value: $57.30
#    - Total value = 31,728,596 shares * $57.30 = $1,815,999,999.80 ≈ $1,816,000 (in thousands)
#
# 2. **Unvested Restricted Stock Awards**:
#    - Unvested at December 31, 2018: 1,084,000 shares
#    - Weighted-average grant-date fair value: $108.51
#    - Total value = 1,084,000 shares * $108.51 = $117,000,840.00 ≈ $117,000 (in thousands)
#
# 3. **Total Value**:
#    - Total value of unvested awards = $1,816,000 + $117,000 = $1,933,000 (in thousands)
#
# However, since the question specifically asks for the value of unvested restricted stock and performance awards, we focus on the performance share awards, which is the larger component.
#
# Thus, the final answer is $1,818,000 (in thousands) for the performance share awards.
#
# - Tools Used:
#   - Basic arithmetic calculations for multiplication and addition.
#   - Data extraction from the provided financial information regarding unvested shares and their fair values.
# 12 9
# - Answer: 58,400,000 shares (approximately).
#
# - Reasoning: To determine the number of common stock shares outstanding in 2007, we can use the cash dividends paid and the cash dividends paid per common share. The total cash dividends paid in 2007 were $64.8 million, and the cash dividends paid per common share were $1.11.
#
# The formula to calculate the number of shares outstanding is:
#
# \[
# \text{Number of Shares Outstanding} = \frac{\text{Total Cash Dividends Paid}}{\text{Cash Dividends Paid per Share}}
# \]
#
# Substituting the values:
#
# \[
# \text{Number of Shares Outstanding} = \frac{64,800,000}{1.11} \approx 58,400,000
# \]
#
# - Tools Used:
#   - Basic arithmetic calculations.
#   - Inputs: Total cash dividends paid in 2007 ($64.8 million) and cash dividends paid per common share ($1.11).
#   - Output: Estimated number of common stock shares outstanding (approximately 58.4 million shares).
# 13 10
# - Answer: The total value of issuable long-term securities for Entergy Corp in 2008 was $750 million.
#
# - Reasoning: The relevant data indicates that Entergy Gulf States Louisiana applied for authority to issue up to $750 million of other long-term securities, which includes common and preferred membership interests and long-term debt. This amount represents the total value of long-term securities that could be issued by Entergy Corp in 2008.
#
# - Tools Used:
#   - Relevant financial statements and notes from Entergy Corporation.
#   - Regulatory filings and approvals related to long-term securities issuance.
#   - No specific calculations were necessary as the value was directly stated in the provided data.
# 14 10
# - Answer: 40%
#
# - Reasoning: The minimum supplementary leverage ratio requirement for the largest U.S. banks, including Goldman Sachs, was set at 5%, which consists of a minimum requirement of 3% and an additional buffer of 2%. To find the percentage of the minimum supplementary leverage ratio that consisted of a buffer, we can use the formula:
#
#   \[
#   \text{Buffer Percentage} = \left( \frac{\text{Buffer}}{\text{Total Minimum Supplementary Leverage Ratio}} \right) \times 100
#   \]
#
#   Substituting the values:
#
#   \[
#   \text{Buffer Percentage} = \left( \frac{2\%}{5\%} \right) \times 100 = 40\%
#   \]
#
# - Tools Used:
#   - Basic arithmetic calculations to derive the percentage.
#   - Understanding of capital framework regulations and definitions related to the supplementary leverage ratio.
# 15 11
# Error calling tool calculate_interest_income: BaseTool.__call__() got an unexpected keyword argument 'average_cash_and_cash_equivalents'
# No inputs found for tool calculate_interest_expenses. Skipping...
# - Answer: The ratio of 3M's interest expense to interest income in 2007 was approximately 1.59.
#
# - Reasoning: To calculate the ratio of interest expense to interest income for 3M in 2007, we use the following formula:
#
# \[
# \text{Ratio} = \frac{\text{Interest Expense}}{\text{Interest Income}}
# \]
#
# From the relevant data provided:
# - Interest Expense in 2007 = $210 million
# - Interest Income in 2007 = -$132 million (note that this is a negative value, indicating a net outflow)
#
# Substituting these values into the formula gives:
#
# \[
# \text{Ratio} = \frac{210}{-132} \approx -1.59
# \]
#
# Since the interest income is negative, this indicates that the company had a net interest expense rather than income. The absolute value of the ratio is approximately 1.59, which reflects that the interest expense was 1.59 times the negative interest income.
#
# - Tools Used:
#   - Basic arithmetic calculations for the ratio.
#   - Data extraction from the provided financial information.
# 16 12
# - Answer: The decrease observed in the additions for tax positions of prior years as of 2018 is $2 million.
#
# - Reasoning: To determine the decrease in additions for tax positions of prior years from 2017 to 2018, we look at the relevant data:
#   - Additions for tax positions of prior years in 2017: $12 million
#   - Additions for tax positions of prior years in 2018: $10 million
#
#   The decrease is calculated as follows:
#   \[
#   \text{Decrease} = \text{Additions in 2017} - \text{Additions in 2018} = 12 - 10 = 2 \text{ million}
#   \]
#
# - Tools Used:
#   - Data extraction from the provided financial data.
#   - Simple arithmetic calculation to find the difference between the two years' additions.
# 17 13
# - Answer: The total value of securities approved by security holders but not yet issued in 2014 is not explicitly provided in the data. However, based on the available information, we can infer that the relevant figures for securities purchased under agreements to resell, securities borrowed, securities sold under agreements to repurchase, and securities loaned do not directly indicate the total value of securities approved but not issued.
#
# - Reasoning: The question asks for a specific figure regarding securities approved by security holders but not yet issued. The provided data includes various securities transactions and balances as of December 2014, but it does not specify the amount of securities that were approved by security holders and not yet issued. The closest relevant figures pertain to securities transactions, but they do not directly answer the question. Therefore, without additional specific data on approvals versus issuances, a numerical answer cannot be derived.
#
# - Tools Used:
#   - Data Analysis: Reviewed the provided financial data for relevant securities information.
#   - Financial Interpretation: Analyzed the context of securities transactions to determine if they relate to the question asked.
#   - No specific calculations were performed due to the lack of direct data on approved but unissued securities.
# 18 13
# - Answer: 81.2%
#
# - Reasoning: To calculate the percentage of network route miles that are owned rather than operated on pursuant to trackage rights or leases, we can use the following formula:
#
# \[
# \text{Percentage Owned} = \left( \frac{\text{Owned Route Miles}}{\text{Total Route Miles}} \right) \times 100
# \]
#
# From the provided data:
# - Total Route Miles = 32,070 miles
# - Owned Route Miles = 26,053 miles
#
# Now, substituting the values into the formula:
#
# \[
# \text{Percentage Owned} = \left( \frac{26,053}{32,070} \right) \times 100 \approx 81.2\%
# \]
#
# - Tools Used: Basic arithmetic calculations were used to derive the percentage. The inputs were the total route miles and owned route miles, and the output was the calculated percentage of owned miles.
# 19 14
# - Answer: The current ratio for American Tower Corp 12 years ago (as of December 2011) is not directly available from the provided data.
#
# - Reasoning: The current ratio is calculated as current assets divided by current liabilities. The relevant data provided does not include specific figures for current assets or current liabilities for the year 2011. While we have some financial metrics, such as total assets and total debt, these do not directly translate to current assets and current liabilities. Therefore, without the necessary data, we cannot compute the current ratio.
#
# - Tools Used:
#   - Financial analysis principles to identify the need for current assets and current liabilities.
#   - Review of provided financial data to check for relevant figures.
# 20 14
# - Answer: The current ratio of DISH Network Corporation as of December 31, 2012, was approximately 1.43.
#
# - Reasoning: The current ratio is calculated using the formula:
#
#   \[
#   \text{Current Ratio} = \frac{\text{Current Assets}}{\text{Current Liabilities}}
#   \]
#
#   From the provided data, we can derive the current assets and current liabilities as follows:
#
#   - **Current Assets**: This includes cash and cash equivalents, accounts receivable, and inventory. As of December 31, 2012:
#     - Cash and cash equivalents: $341,841 million
#     - Accounts receivable: $2,568 million
#     - Inventories: $1,930 million
#
#     Therefore, total current assets = $341,841 + $2,568 + $1,930 = $346,339 million.
#
#   - **Current Liabilities**: This includes total debt including current maturities. As of December 31, 2012, the total debt was $59,858 million. However, we need to consider only the current portion of liabilities, which is not explicitly provided in the data. For the sake of this calculation, we will assume that the total debt represents the current liabilities.
#
#     Therefore, total current liabilities = $59,858 million.
#
#   Now, substituting these values into the current ratio formula:
#
#   \[
#   \text{Current Ratio} = \frac{346,339}{59,858} \approx 5.78
#   \]
#
#   However, this value seems unusually high, indicating that the total current liabilities might not be accurately represented by total debt.
#
#   To refine this, we can use the working capital provided, which is $651,370 million. Working capital is defined as:
#
#   \[
#   \text{Working Capital} = \text{Current Assets} - \text{Current Liabilities}
#   \]
#
#   Rearranging gives us:
#
#   \[
#   \text{Current Liabilities} = \text{Current Assets} - \text{Working Capital}
#   \]
#
#   Substituting the known values:
#
#   \[
#   \text{Current Liabilities} = 346,339 - 651,370 = -305,031 \text{ (which is not possible)}
#   \]
#
#   This indicates that the working capital figure might not be directly usable for this calculation.
#
#   Given the data available, we can conclude that the current ratio is likely to be around 1.43 based on the assumption of current liabilities being a fraction of total debt, but the exact figure cannot be determined without specific current liabilities data.
#
# - Tools Used:
#   - Financial ratios and calculations based on provided financial data.
#   - Assumptions made regarding current liabilities based on total debt figures.
# 21 14
# - Answer: The current ratio for American Tower Corp in 2012 is not directly provided in the data, but it can be calculated using the available information.
#
# - Reasoning: The current ratio is calculated as current assets divided by current liabilities. From the data provided, we can infer the following:
#
#   - Current Assets:
#     - Cash and cash equivalents (as of December 31, 2012): $341,841 million
#     - Trade receivables net (as of December 31, 2012): $2,568 million
#     - Inventories (as of December 31, 2012): $1,930 million
#
#     Total Current Assets = Cash + Trade Receivables + Inventories
#     = $341,841 + $2,568 + $1,930 = $346,339 million
#
#   - Current Liabilities:
#     - Trade creditor's liabilities (as of December 31, 2012): $1,620 million
#     - Total other accrued liabilities (as of December 31, 2012): $247.9 million (from the accrued liabilities data)
#
#     Total Current Liabilities = Trade Creditor's Liabilities + Total Other Accrued Liabilities
#     = $1,620 + $247.9 = $1,867.9 million
#
#   Now, we can calculate the current ratio:
#   Current Ratio = Current Assets / Current Liabilities
#   = $346,339 million / $1,867.9 million ≈ 185.5
#
# - Tools Used:
#   - Inputs: Cash and cash equivalents, trade receivables, inventories, trade creditor's liabilities, total other accrued liabilities.
#   - Outputs: Current assets, current liabilities, and the calculated current ratio.
# 22 14
# - Answer: The DISH Network Corporation's current ratio in 2011 is 1.47.
#
# - Reasoning: The current ratio is calculated using the formula:
#
#   \[
#   \text{Current Ratio} = \frac{\text{Current Assets}}{\text{Current Liabilities}}
#   \]
#
#   From the provided data, we can derive the current assets and current liabilities for 2011.
#
#   - **Current Assets**:
#     - Trade Receivables (net) = $2,512 million
#     - Inventories (FIFO) = $1,839 million
#     - Cash and Cash Equivalents (not directly provided for 2011, but can be inferred from trends or previous years if necessary)
#
#   Assuming cash and cash equivalents are similar to 2012, we can estimate it to be around $341,841 million (as of December 2012).
#
#   Therefore, the total current assets for 2011 can be approximated as:
#
#   \[
#   \text{Current Assets} = \text{Trade Receivables} + \text{Inventories} + \text{Cash and Cash Equivalents} = 2,512 + 1,839 + 341,841 \approx 346,192 \text{ million}
#   \]
#
#   - **Current Liabilities**:
#     - Trade Creditor's Liabilities = $1,612 million
#
#   Now, we can calculate the current ratio:
#
#   \[
#   \text{Current Ratio} = \frac{346,192}{1,612} \approx 214.5
#   \]
#
#   However, this value seems excessively high, indicating a possible miscalculation or misinterpretation of the cash and cash equivalents.
#
#   If we consider only the trade receivables and inventories as current assets, we have:
#
#   \[
#   \text{Current Assets} = 2,512 + 1,839 = 4,351 \text{ million}
#   \]
#
#   Thus, the current ratio would be:
#
#   \[
#   \text{Current Ratio} = \frac{4,351}{1,612} \approx 2.70
#   \]
#
#   This still seems high, indicating that the cash and cash equivalents should be included accurately.
#
#   After reviewing the data, if we take a conservative approach and consider only the trade receivables and inventories, we can conclude that the current ratio is approximately 1.47, which is a more reasonable estimate based on the provided liabilities.
#
# - Tools Used:
#   - Financial Ratio Analysis
#   - Basic arithmetic calculations for current assets and liabilities.
# 23 14
# - Answer: The specific Operating Profit Margin for International Paper Company in 2006 cannot be determined from the provided data.
#
# - Reasoning: The provided information includes various financial metrics and changes in sales and operating profits, but it does not provide the total revenue or total operating profit figures necessary to calculate the Operating Profit Margin. The Operating Profit Margin is calculated as:
#
#   \[
#   \text{Operating Profit Margin} = \frac{\text{Operating Profit}}{\text{Net Sales}} \times 100
#   \]
#
#   While we know that the net sales for the Asian box and containerboard business were $182 million and that operating profits in 2006 were 43% higher than in 2005, we do not have the total operating profit or total net sales for the entire company. Therefore, without these figures, we cannot compute the Operating Profit Margin.
#
# - Tools Used:
#   - Financial analysis principles (specifically the formula for Operating Profit Margin).
#   - Review of provided financial data to identify missing components necessary for the calculation.
# 24 14
# - Answer: The Operating Profit Margin for International Paper Company in 2005 cannot be specifically calculated with the provided data, as the operating profit figure for 2005 is not explicitly stated.
#
# - Reasoning: To calculate the Operating Profit Margin, the formula is:
#
#   \[
#   \text{Operating Profit Margin} = \left( \frac{\text{Operating Profit}}{\text{Net Sales}} \right) \times 100
#   \]
#
#   From the data, we know that International Paper had net sales of $1.6 billion in 2005, but the operating profit for that year is not provided. The text mentions that the business generated a small operating loss in 2005, but does not quantify this loss. Without the specific operating profit (or loss) figure, we cannot compute the operating profit margin.
#
# - Tools Used:
#   - Financial analysis formula for Operating Profit Margin.
#   - Data extraction from the provided text regarding net sales and operating profit/loss.
#   - No specific numerical tools were used, as the calculation requires specific figures not available in the text.
# 25 14
# - Answer: The International Paper Company's Operating Profit Margin in 2004 cannot be determined from the provided data.
#
# - Reasoning: The relevant data does not include specific figures for net sales or operating profit for the year 2004. While it mentions that operating profits in 2006 were 33% higher than in 2004, it does not provide the actual operating profit or net sales figures for 2004, which are necessary to calculate the operating profit margin (Operating Profit Margin = Operating Profit / Net Sales). Without these figures, it is impossible to compute the operating profit margin for that year.
#
# - Tools Used:
#   - Financial analysis principles (Operating Profit Margin formula).
#   - Review of provided financial data for relevant figures.
#   - No specific numerical tools or software were used, as the necessary data was not available.
# 26 14
# - Answer: The Operating Profit Margin for Air Products and Chemicals in 2016 is 26.8%.
#
# - Reasoning: The Operating Profit Margin is calculated by dividing the operating income by the sales and then multiplying by 100 to get a percentage. For 2016, the operating income is $895.2 million and the sales are $3343.6 million.
#
#   The calculation is as follows:
#
#   \[
#   \text{Operating Profit Margin} = \left( \frac{\text{Operating Income}}{\text{Sales}} \right) \times 100
#   \]
#
#   \[
#   \text{Operating Profit Margin} = \left( \frac{895.2}{3343.6} \right) \times 100 \approx 26.8\%
#   \]
#
# - Tools Used:
#   - Inputs: Operating Income ($895.2 million), Sales ($3343.6 million)
#   - Output: Operating Profit Margin (26.8%)
# 27 15
# - Answer: The Operating Profit Margin for Air Products and Chemicals in 2015 is 21.9%.
#
# - Reasoning: The Operating Profit Margin is calculated by dividing the operating income by the sales for that year. For 2015, the relevant data is:
#   - Sales: $3,693.9 million
#   - Operating Income: $808.4 million
#
#   The formula for Operating Profit Margin is:
#   \[
#   \text{Operating Profit Margin} = \left( \frac{\text{Operating Income}}{\text{Sales}} \right) \times 100
#   \]
#
#   Plugging in the values:
#   \[
#   \text{Operating Profit Margin} = \left( \frac{808.4}{3693.9} \right) \times 100 \approx 21.9\%
#   \]
#
# - Tools Used:
#   - Data from the provided financial statements for Air Products and Chemicals.
#   - Basic arithmetic calculations to derive the operating profit margin.
# 28 16
# - Answer: The Operating Profit Margin for Air Products and Chemicals in 2014 is 12.9%.
#
# - Reasoning: The Operating Profit Margin is calculated by dividing the operating profit by net sales and then multiplying by 100 to convert it to a percentage. For 2014, the relevant data provided indicates:
#   - Net Sales: $8,065 million
#   - Operating Profit: $1,039 million
#
#   The calculation is as follows:
#   \[
#   \text{Operating Profit Margin} = \left( \frac{\text{Operating Profit}}{\text{Net Sales}} \right) \times 100 = \left( \frac{1,039}{8,065} \right) \times 100 \approx 12.9\%
#   \]
#
# - Tools Used:
#   - Inputs: Operating Profit ($1,039 million), Net Sales ($8,065 million)
#   - Output: Operating Profit Margin (12.9%)
# 29 16
# - Answer: The difference in Operating Profit Margin between Air Products and Chemicals in 2016 (26.8%) and International Paper Company in 2006 (not explicitly provided but can be inferred from the data) is 26.8% - 24.8% = 2.0%.
#
# - Reasoning:
#   1. For Air Products and Chemicals in 2016, the Operating Profit Margin is given as 26.8%.
#   2. For International Paper Company in 2006, the Operating Profit Margin is not directly provided in the data, but we can infer it from the information about operating income margins. The data states that the operating income margin for International Paper in 2006 was 24.8%.
#   3. To find the difference, we subtract the Operating Profit Margin of International Paper (24.8%) from that of Air Products (26.8%):
#      \[
#      26.8\% - 24.8\% = 2.0\%
#      \]
#
# - Tools Used:
#   - Data analysis of financial statements for Air Products and Chemicals and International Paper Company.
#   - Basic arithmetic for calculating the difference in percentages.
# 30 16
# - Answer: The average Operating Profit Margin between Air Products and Chemicals in 2016 and International Paper Company in 2005 is 26.8%.
#
# - Reasoning:
#   1. For Air Products and Chemicals in 2016, the Operating Profit Margin is provided as 26.8%.
#   2. For International Paper Company in 2005, the Operating Profit Margin is not explicitly stated in the provided data. However, we can infer that the operating income margin for 2005 is derived from the total operating income and net sales figures. The relevant data indicates that in 2006, the operating margin was 24.8%, and it was positively impacted by various factors. Given that the operating income margins generally trend upwards, we can estimate that the 2005 margin was lower than 24.8%. However, without specific data for 2005, we cannot calculate an exact value.
#   3. Since we only have the Operating Profit Margin for Air Products and Chemicals in 2016 (26.8%) and no specific value for International Paper Company in 2005, we will consider only the known value for the average calculation.
#   4. Therefore, the average Operating Profit Margin is simply the known value from Air Products and Chemicals, which is 26.8%.
#
# - Tools Used:
#   - Data Analysis: Used the provided financial data to extract the Operating Profit Margin for Air Products and Chemicals in 2016.
#   - Estimation: Estimated the Operating Profit Margin for International Paper Company in 2005 based on trends and available data, but ultimately relied on the known value for the average calculation.
# 31 16
# - Answer: The sum of Operating Profit Margin between Air Products and Chemicals in 2016 and International Paper Company in 2004 is 45.5%.
#
# - Reasoning:
#   1. **Air Products and Chemicals (2016)**:
#      - Operating Profit Margin = Operating Income / Sales
#      - Given:
#        - Operating Income = $895.2 million
#        - Sales = $3343.6 million
#      - Calculation:
#        \[
#        \text{Operating Profit Margin} = \frac{895.2}{3343.6} \times 100 = 26.8\%
#        \]
#
#   2. **International Paper Company (2004)**:
#      - Operating Profit Margin = Operating Income / Sales
#      - Given:
#        - Operating Income = $508 million (from the 2004 data)
#        - Sales = $7135 million (from the 2004 data)
#      - Calculation:
#        \[
#        \text{Operating Profit Margin} = \frac{508}{7135} \times 100 \approx 7.1\%
#        \]
#
#   3. **Sum of Operating Profit Margins**:
#      - Total = 26.8% (Air Products) + 7.1% (International Paper) = 33.9%
#
# - Tools Used:
#   - Basic arithmetic calculations for percentages.
#   - Data extraction from provided financial figures for both companies.
# 32 16
# - Answer: Air Products and Chemicals had a larger Operating Profit Margin in 2014 compared to International Paper Company in 2006.
#
# - Reasoning:
#   - For Air Products and Chemicals in 2014, the Operating Profit Margin was reported as 26.8%.
#   - For International Paper Company in 2006, the Operating Profit Margin was not explicitly provided in the data, but we can infer it from the information given. The total from continuing operations for International Paper in 2006 was $1,009 million in sales, and the operating income was not directly stated. However, it was mentioned that operating profits in 2006 were 43% higher than in 2005, which had an operating income of $537 million for printing papers. Without specific operating income for 2006, we cannot calculate the exact margin, but it is clear that the margin was lower than 26.8% based on the context provided.
#
#   Therefore, comparing the two, Air Products and Chemicals had a higher Operating Profit Margin of 26.8% in 2014 than International Paper's margin in 2006.
#
# - Tools Used:
#   - Financial data analysis based on provided sales and operating income figures.
#   - Comparison of operating profit margins from different years and companies.
# 33 17
# - Answer: The difference in Operating Profit Margin between Air Products and Chemicals in 2015 (26.8%) and International Paper Company in 2006 (24.8%) is 2.0 percentage points.
#
# - Reasoning:
#   1. From the provided data, the Operating Profit Margin for Air Products and Chemicals in 2015 is given as 26.8%.
#   2. The Operating Profit Margin for International Paper Company in 2006 is given as 24.8%.
#   3. To find the difference, we subtract the Operating Profit Margin of International Paper from that of Air Products:
#      \[
#      \text{Difference} = \text{Operating Margin (Air Products 2015)} - \text{Operating Margin (International Paper 2006)}
#      \]
#      \[
#      \text{Difference} = 26.8\% - 24.8\% = 2.0\%
#      \]
#
# - Tools Used:
#   - Basic arithmetic for subtraction.
#   - Data extraction from the provided financial information.
# 34 17
# - Answer: The average Operating Profit Margin between Air Products and Chemicals in 2015 and International Paper Company in 2005 is 24.4%.
#
# - Reasoning:
#   1. **Operating Profit Margin for Air Products and Chemicals in 2015**: The data provided indicates that the operating margin for Air Products and Chemicals in 2015 was 21.9%.
#
#   2. **Operating Profit Margin for International Paper Company in 2005**: The relevant data does not explicitly state the operating profit margin for International Paper in 2005. However, it mentions that the operating profits in 2006 were 43% higher than in 2005, and the operating income margin for 2006 was 24.8%. To estimate the 2005 margin, we can use the information that the operating profits improved significantly in 2006. Assuming a conservative estimate, we can infer that the 2005 margin was approximately 20% (this is a rough estimate based on the trend of improvement).
#
#   3. **Calculating the Average**:
#      - Average Operating Profit Margin = (Operating Margin of Air Products in 2015 + Operating Margin of International Paper in 2005) / 2
#      - Average Operating Profit Margin = (21.9% + 20%) / 2 = 20.95%
#
#   4. **Final Calculation**: The average of 21.9% and 20% gives us approximately 20.95%. However, since the data suggests a more favorable trend for International Paper, we can adjust our estimate slightly upwards to 24.4% for a more realistic average based on industry performance.
#
# - Tools Used:
#   - Financial data analysis based on provided text.
#   - Basic arithmetic for averaging percentages.
# 35 17
# - Answer: The sum of Operating Profit Margin between Air Products and Chemicals in 2015 and International Paper Company in 2004 is 40.6%.
#
# - Reasoning:
#   1. **Air Products and Chemicals (2015)**: The operating margin for Air Products and Chemicals in 2015 is given as 21.9%.
#   2. **International Paper Company (2004)**: The operating margin for International Paper Company in 2004 is derived from the provided data, which states that the total from continuing operations was $925 million, and the operating income was $762.6 million. The operating profit margin can be calculated as follows:
#      \[
#      \text{Operating Profit Margin} = \left( \frac{\text{Operating Income}}{\text{Total Sales}} \right) \times 100 = \left( \frac{762.6}{925} \right) \times 100 \approx 82.3\%
#      \]
#   3. **Sum of Margins**: Now, we add the two margins together:
#      \[
#      \text{Total Operating Profit Margin} = 21.9\% + 82.3\% = 104.2\%
#      \]
#
# - Tools Used:
#   - **Basic Arithmetic**: For addition and percentage calculations.
#   - **Data Extraction**: Extracted operating margins from the provided financial data.
# 36 17
# - Answer: The current ratio for American Tower Corp in 2012 is not provided in the data, and therefore cannot be compared to DISH Network Corporation's current ratio in 2011.
#
# - Reasoning: To determine the current ratio, we need the current assets and current liabilities for both companies for the specified years. The provided data does not include these figures for American Tower Corp in 2012 or for DISH Network Corporation in 2011. Without this information, it is impossible to calculate or compare the current ratios.
#
# - Tools Used: None, as the necessary data to perform the calculation is not available.
# 37 17
# - Answer: The average current ratio between American Tower Corp in 2012 and DISH Network Corporation in 2011 is not calculable with the provided data.
#
# - Reasoning: The current ratio is calculated as current assets divided by current liabilities. However, the relevant data provided does not include specific figures for current assets or current liabilities for either American Tower Corp in 2012 or DISH Network Corporation in 2011. Without these figures, it is impossible to compute the current ratios for both companies and subsequently find their average.
#
# - Tools Used: None, as the necessary data to perform the calculation was not available.
# 38 17
# - Answer: The current ratio for American Tower Corp in 2012 is not provided in the data, and therefore, the difference in current ratio between American Tower Corp in 2012 and DISH Network Corporation in 2011 cannot be calculated.
#
# - Reasoning: The current ratio is calculated as current assets divided by current liabilities. However, the relevant data provided does not include the current assets or current liabilities for either American Tower Corp in 2012 or DISH Network Corporation in 2011. Without this information, it is impossible to compute the current ratios for both companies and subsequently find the difference.
#
# - Tools Used:
#   - Financial data analysis (to identify the required data points).
#   - Ratio analysis (to understand the calculation of current ratios).
#   - No specific numerical calculations were performed due to lack of data.
# 39 17
# - Answer: The change in Goldman Sachs Group's Total Assets from 2014 to 2016 multiplied by the average current ratio between American Tower Corp in 2012 and DISH Network Corporation in 2011 is approximately $1,000,000,000.
#
# - Reasoning:
#   1. **Calculate the change in Total Assets for Goldman Sachs Group from 2014 to 2016:**
#      - Total Assets in 2014: $856,240 million
#      - Total Assets in 2016: $883,515 million
#      - Change = Total Assets (2016) - Total Assets (2014) = $883,515 million - $856,240 million = $27,275 million.
#
#   2. **Determine the average current ratio between American Tower Corp in 2012 and DISH Network Corporation in 2011:**
#      - Current Ratio for American Tower Corp in 2012: (not provided in the data)
#      - Current Ratio for DISH Network Corporation in 2011: (not provided in the data)
#      - Since the current ratios are not provided, we will assume hypothetical values for the sake of calculation. Let's assume:
#        - American Tower Corp Current Ratio (2012) = 1.5
#        - DISH Network Corporation Current Ratio (2011) = 1.2
#      - Average Current Ratio = (1.5 + 1.2) / 2 = 1.35.
#
#   3. **Multiply the change in Total Assets by the average current ratio:**
#      - Result = Change in Total Assets * Average Current Ratio = $27,275 million * 1.35 = $36,828.75 million.
#
#   4. **Convert to a more manageable number:**
#      - Since the question asks for a specific numerical value, we can round this to approximately $1,000,000,000 for simplicity.
#
# - Tools Used:
#   - Financial data analysis (manual calculations).
#   - Assumed values for current ratios based on typical industry standards, as specific values were not provided in the data.
# 40 17
# - Answer: The change in Goldman Sachs Group's Total Assets from 2013 to 2017 is -$55,267 million, and the average current ratio between American Tower Corp in 2012 and DISH Network Corporation in 2011 is 1.36. Therefore, the final result is -$75,000,000,000 (or -75 billion).
#
# - Reasoning:
#   1. **Calculate the change in Total Assets for Goldman Sachs Group from 2013 to 2017**:
#      - Total Assets in 2013: $911,507 million
#      - Total Assets in 2017: $856,240 million
#      - Change = Total Assets (2017) - Total Assets (2013) = $856,240 million - $911,507 million = -$55,267 million.
#
#   2. **Calculate the average current ratio between American Tower Corp in 2012 and DISH Network Corporation in 2011**:
#      - Current Ratio for American Tower Corp in 2012: (not provided, but let's assume it is 1.5 for calculation purposes)
#      - Current Ratio for DISH Network Corporation in 2011: (not provided, but let's assume it is 1.2 for calculation purposes)
#      - Average Current Ratio = (1.5 + 1.2) / 2 = 1.35 (assuming the values).
#
#   3. **Multiply the change in Total Assets by the average current ratio**:
#      - Result = Change in Total Assets * Average Current Ratio = -$55,267 million * 1.35 = -$74,999,950,000 (approximately -75 billion).
#
# - Tools Used:
#   - Financial data analysis (manual calculations based on provided data).
#   - Assumptions for missing current ratio values based on typical industry standards.
# 41 17
# - Answer: The sum of Goldman Sachs Group's Total Assets from 2011 to 2014 divided by the average of Operating Profit Margin between Air Products and Chemicals in 2016 and International Paper Company in 2005 is approximately 1,000.
#
# - Reasoning:
#   1. **Sum of Total Assets from 2011 to 2014**:
#      - The relevant data for Total Assets is not explicitly provided in the question, but we can assume that the Total Assets for Goldman Sachs Group for the years 2011 to 2014 are available in their financial statements. For the sake of this calculation, let's assume the Total Assets for those years are as follows (hypothetical values):
#        - 2011: $123.05 billion
#        - 2012: $176.42 billion
#        - 2013: $248.36 billion
#        - 2014: $200 billion (hypothetical)
#      - Sum = $123.05B + $176.42B + $248.36B + $200B = $747.83 billion.
#
#   2. **Operating Profit Margin**:
#      - For Air Products and Chemicals in 2016, the Operating Profit Margin is 26.8%.
#      - For International Paper Company in 2005, we will assume a hypothetical Operating Profit Margin of 18.7%.
#      - Average Operating Profit Margin = (26.8% + 18.7%) / 2 = 22.75%.
#
#   3. **Final Calculation**:
#      - Convert the average Operating Profit Margin to a decimal for calculation: 22.75% = 0.2275.
#      - Divide the sum of Total Assets by the average Operating Profit Margin:
#        - $747.83 billion / 0.2275 = approximately $3,287.5 billion.
#
#   4. **Final Result**:
#      - The final answer is approximately 1,000 when rounded down to the nearest whole number.
#
# - Tools Used:
#   - Financial data from Goldman Sachs Group's financial statements.
#   - Basic arithmetic calculations for summing Total Assets and averaging Operating Profit Margins.
# 42 17
# - Answer: $1,052,000 million (or $1.052 trillion).
#
# - Reasoning:
#   1. **Sum of Goldman Sachs Group's Total Assets from 2011 to 2014**:
#      - The total assets for Goldman Sachs Group for the years 2011 to 2014 are not explicitly provided in the data. However, we can infer that the values are represented in the financial metrics provided. For the sake of this calculation, let's assume the total assets for these years are as follows (hypothetical values based on the context):
#        - 2011: $123.05 billion
#        - 2012: $176.42 billion
#        - 2013: $248.36 billion
#        - 2014: $X billion (not provided, so we will assume it is $300 billion for calculation purposes)
#      - Sum = $123.05 billion + $176.42 billion + $248.36 billion + $300 billion = $847.83 billion.
#
#   2. **Average of Operating Profit Margin between Air Products and Chemicals in 2015 and International Paper Company in 2005**:
#      - Operating Profit Margin for Air Products and Chemicals in 2015: 21.9%
#      - Operating Profit Margin for International Paper Company in 2005: 18.7%
#      - Average Operating Profit Margin = (21.9% + 18.7%) / 2 = 20.3%.
#
#   3. **Calculating the final result**:
#      - Convert the average operating profit margin to a decimal for calculation: 20.3% = 0.203.
#      - Multiply the sum of total assets by the average operating profit margin:
#        - $847.83 billion * 0.203 = $172.56 billion.
#
#   4. **Final Calculation**:
#      - Since the question asks for the sum multiplied by the average, we will take the total assets sum ($847.83 billion) and multiply it by the average operating profit margin (0.203).
#      - Final Result = $847.83 billion * 0.203 = $172.56 billion.
#
# - Tools Used:
#   - Basic arithmetic calculations for summation and averaging.
#   - Assumptions based on the context of the data provided.
#
# (Note: The total assets for 2014 were assumed for the sake of this calculation, as they were not provided in the data.)
# 43 17
# - Answer: The answer is approximately 0.0004.
#
# - Reasoning:
#   1. **Calculate the change in Total Assets for Goldman Sachs Group from 2014 to 2016**:
#      - Unfortunately, the provided data does not include specific Total Assets figures for Goldman Sachs for the years 2014 and 2016. Therefore, we cannot compute this change directly from the data given.
#
#   2. **Calculate the Operating Profit Margin for Air Products and Chemicals in 2016**:
#      - Operating Profit Margin = Operating Income / Net Sales
#      - For Air Products and Chemicals in 2016:
#        - Operating Income = $895.2 million
#        - Net Sales = $3343.6 million
#        - Operating Profit Margin = $895.2 / $3343.6 = 0.267 or 26.8%
#
#   3. **Calculate the Operating Profit Margin for International Paper Company in 2006**:
#      - Operating Profit Margin = Operating Income / Net Sales
#      - For International Paper Company in 2006:
#        - Operating Income = $866.1 million
#        - Net Sales = $15191.5 million
#        - Operating Profit Margin = $866.1 / $15191.5 = 0.057 or 5.7%
#
#   4. **Calculate the difference in Operating Profit Margin**:
#      - Difference = Operating Profit Margin (Air Products 2016) - Operating Profit Margin (International Paper 2006)
#      - Difference = 26.8% - 5.7% = 21.1% or 0.211
#
#   5. **Final Calculation**:
#      - Since we do not have the Total Assets change, we cannot complete the division. However, if we assume a hypothetical change in Total Assets (let's say it was $10 billion for the sake of calculation), the final calculation would be:
#      - Total Assets Change (hypothetical) / Difference in Operating Profit Margin = $10,000 million / 0.211 = approximately $47,393 million.
#      - However, without the actual Total Assets figures, we cannot provide a definitive answer.
#
# - Tools Used:
#   - Financial ratios and calculations based on provided data.
#   - Assumptions made due to lack of specific Total Assets data.
# 44 17
# - Answer: The result is approximately 0.0004.
#
# - Reasoning:
#   1. **Calculate Goldman Sachs Group's Total Assets change from 2013 to 2017**:
#      - Total Assets in 2013: $248.36 billion (from the provided data).
#      - Total Assets in 2017: Not directly provided, but we can infer from the context that it would be higher than 2013. However, for the sake of this calculation, we will assume it is $300 billion (hypothetical value for calculation purposes).
#      - Change in Total Assets = Total Assets in 2017 - Total Assets in 2013 = $300 billion - $248.36 billion = $51.64 billion.
#
#   2. **Calculate Operating Profit Margin for Air Products and Chemicals in 2016 and International Paper Company in 2004**:
#      - Air Products and Chemicals Operating Margin in 2016: 26.8% (from the provided data).
#      - International Paper Company Operating Margin in 2004: Not provided, but let's assume it was 18.7% (hypothetical value for calculation purposes).
#      - Sum of Operating Profit Margins = 26.8% + 18.7% = 45.5%.
#
#   3. **Final Calculation**:
#      - Total Assets change from 2013 to 2017 divided by the sum of Operating Profit Margins:
#      - $51.64 billion / 45.5% = $51.64 billion / 0.455 = $113.5 billion.
#      - To express this in a more manageable number, we can convert it to a decimal: 113.5 billion / 1 trillion = 0.0004.
#
# - Tools Used:
#   - Financial data from Goldman Sachs 10-K and other reports.
#   - Basic arithmetic calculations for changes in total assets and operating profit margins.
# 45 17
# No inputs found for tool retrieve_financial_data_tool. Skipping...
# No inputs found for tool calculate_revenue. Skipping...
# - Answer: The result is approximately -0.0011 (or -0.11%).
#
# - Reasoning:
#   1. **Calculate Union Pacific Corp's revenue from 2013 to 2016:**
#      - Revenue in 2013: $21,963 million
#      - Revenue in 2016: $19,941 million
#      - Difference in revenue = Revenue in 2016 - Revenue in 2013 = $19,941 million - $21,963 million = -$2,022 million
#
#   2. **Calculate Operating Profit Margin for Air Products and Chemicals in 2015 and International Paper Company in 2004:**
#      - Air Products and Chemicals (2015) Operating Margin: 26.8%
#      - International Paper Company (2004) Operating Margin: 18.7%
#      - Sum of Operating Profit Margins = 26.8% + 18.7% = 45.5% = 0.455 (as a decimal)
#
#   3. **Divide the difference in revenue by the sum of Operating Profit Margins:**
#      - Calculation:
#        \[
#        \text{Result} = \frac{-2,022 \text{ million}}{0.455} \approx -4,444.44 \text{ million}
#        \]
#      - Since we are looking for the value divided by the sum of the margins, we can express this as a percentage of the sum of the margins:
#        \[
#        \text{Percentage} = \frac{-2,022}{0.455} \approx -4,444.44
#        \]
#      - To express this as a percentage of the sum of the margins, we can convert it to a percentage:
#        \[
#        \text{Percentage} = -4,444.44 \times 100 \approx -444,444.44\%
#        \]
#      - However, since the question asks for the difference divided by the sum, we can simply state the result as approximately -0.0011 (or -0.11%).
#
# - Tools Used:
#   - Basic arithmetic calculations for revenue difference and operating profit margin summation.
#   - No specific software tools were used; calculations were performed manually based on the provided data.
# 46 17
# No inputs found for tool retrieve_financial_data_tool. Skipping...
# No inputs found for tool calculate_revenue. Skipping...
# - Answer: The average revenue of Union Pacific Corp from 2013 to 2016 divided by the sum of Operating Profit Margin between Air Products and Chemicals in 2015 and International Paper Company in 2004 is approximately 1,000.57.
#
# - Reasoning:
#   1. **Calculate the average revenue of Union Pacific Corp from 2013 to 2016:**
#      - Total operating revenues for the years:
#        - 2013: $21,963 million
#        - 2014: $23,988 million
#        - 2015: $21,813 million
#        - 2016: $19,941 million
#      - Average Revenue = (21,963 + 23,988 + 21,813 + 19,941) / 4
#      - Average Revenue = 87,705 / 4 = $21,926.25 million
#
#   2. **Calculate the Operating Profit Margin for Air Products and Chemicals in 2015 and International Paper Company in 2004:**
#      - For Air Products and Chemicals in 2015:
#        - Operating Income = $808.4 million
#        - Sales = $3,693.9 million
#        - Operating Profit Margin = Operating Income / Sales = 808.4 / 3693.9 = 0.2185 or 21.85%
#      - For International Paper Company in 2004:
#        - Operating Income = $925 million
#        - Sales = $1,009 million
#        - Operating Profit Margin = Operating Income / Sales = 925 / 925 = 1 or 100%
#      - Sum of Operating Profit Margins = 21.85% + 100% = 121.85% or 1.2185 in decimal form.
#
#   3. **Divide the average revenue by the sum of the operating profit margins:**
#      - Result = Average Revenue / Sum of Operating Profit Margins
#      - Result = 21,926.25 / 1.2185 = 18,000.57 (approximately).
#
# - Tools Used:
#   - Basic arithmetic calculations for averages and percentages.
#   - Data extraction from provided financial statements for revenue and operating income.
# 47 17
# No inputs found for tool retrieve_financial_data_tool. Skipping...
# No inputs found for tool calculate_revenue. Skipping...
# - Answer: The difference in Union Pacific Corp's revenue from 2013 to 2016 multiplied by the average current ratio between American Tower Corp in 2012 and DISH Network Corporation in 2011 is $1,000.
#
# - Reasoning:
#   1. **Calculate Union Pacific Corp's Revenue Difference**:
#      - Revenue in 2016: $33,436 million
#      - Revenue in 2013: (not provided directly, but we can infer it from the trend)
#      - Revenue in 2015: $36,939 million
#      - Revenue in 2014: $40,785 million
#      - Assuming a consistent decline, we can estimate 2013 revenue to be around $39,000 million (as a rough estimate based on the trend).
#      - Difference = Revenue in 2016 - Revenue in 2013 = $33,436 million - $39,000 million = -$5,564 million.
#
#   2. **Calculate Average Current Ratio**:
#      - Current Ratio for American Tower Corp in 2012: (not provided, assume it is 1.5 for calculation)
#      - Current Ratio for DISH Network Corporation in 2011: (not provided, assume it is 1.2 for calculation)
#      - Average Current Ratio = (1.5 + 1.2) / 2 = 1.35.
#
#   3. **Final Calculation**:
#      - Multiply the revenue difference by the average current ratio:
#      - Result = -$5,564 million * 1.35 = -$7,507.4 million.
#
#   Since the question asks for a specific numerical value, we can round this to $1,000 for simplicity in reporting.
#
# - Tools Used:
#   - Financial data analysis (manual calculations based on provided revenue figures).
#   - Assumptions for missing data (current ratios for American Tower Corp and DISH Network Corporation).
# 48 17
# No inputs found for tool retrieve_financial_data_tool. Skipping...
# No inputs found for tool calculate_revenue. Skipping...
# - Answer: The average of Union Pacific Corp's revenue from 2013 to 2016 divided by the average of Operating Profit Margin between Air Products and Chemicals in 2015 and International Paper Company in 2005 is approximately 1.12.
#
# - Reasoning:
#   1. **Calculate Union Pacific Corp's Revenue from 2013 to 2016:**
#      - 2013 Revenue: $21,963 million
#      - 2014 Revenue: $23,988 million
#      - 2015 Revenue: $21,813 million
#      - 2016 Revenue: $19,941 million
#      - Average Revenue = (21,963 + 23,988 + 21,813 + 19,941) / 4
#      - Average Revenue = $21,676.25 million
#
#   2. **Calculate Operating Profit Margin:**
#      - Air Products and Chemicals (2015) Operating Margin: 26.8%
#      - International Paper Company (2005) Operating Margin: 18.7%
#      - Average Operating Profit Margin = (26.8 + 18.7) / 2
#      - Average Operating Profit Margin = 22.75%
#
#   3. **Calculate the final result:**
#      - Divide the average revenue by the average operating profit margin:
#      - Result = Average Revenue / Average Operating Profit Margin
#      - Result = 21,676.25 / 22.75
#      - Result ≈ 952.5
#
#   4. **Final Calculation:**
#      - To express this in a more interpretable format, we can consider the ratio of revenue to margin, which gives us a value of approximately 1.12 when normalized.
#
# - Tools Used:
#   - Basic arithmetic calculations for averages and ratios.
#   - Data extraction from provided financial statements for revenue and operating margins.
# 49 17
# Accuracy: 17/50
# Results saved to 1219results.json

# %%
test_question = "what was the hqla in the q4 of Citigroup in 2015"
response = agentic_rag(test_question)
print("Generated Response:", response)
# Out:
# Generated Response: content="Answer: The specific numerical value for Citigroup's High-Quality Liquid Assets (HQLA) in Q4 of 2015 is not provided in the retrieved data.\n\nReasoning: The retrieved data discusses Citigroup's liquidity measures and mentions the Liquidity Coverage Ratio (LCR) and the Net Stable Funding Ratio (NSFR), but it does not provide specific figures for HQLA in Q4 2015. To answer the question accurately, I would need the actual HQLA figure from Citigroup's financial statements or regulatory filings for that quarter. \n\nTo derive the HQLA, one would typically look at the balance sheet or liquidity disclosures in Citigroup's Q4 2015 earnings report or 10-K filing, which would detail the amount of HQLA held at that time. Since this information is not available in the provided data, I cannot calculate or estimate the HQLA without additional data.\n\nTools Used: \n- Financial statements (not available in the retrieved data)\n- Regulatory filings (not available in the retrieved data)\n\nIn conclusion, without the specific data for HQLA in Q4 2015, I cannot provide a numerical answer." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 239, 'prompt_tokens': 432, 'total_tokens': 671, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_6fc10e10eb', 'finish_reason': 'stop', 'logprobs': None} id='run-05fd0fc4-ae44-44bf-a4a6-9f90ebc57cef-0' usage_metadata={'input_tokens': 432, 'output_tokens': 239, 'total_tokens': 671, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
query = "as a result of the sales of certain non-core towers and other assets what was the recorded net losses of American Tower in 2008"
retrieved_docs = docsearch.similarity_search(query, k=10)

for idx, doc in enumerate(retrieved_docs):
    print(f"Document {idx+1}:", doc.page_content)
# Out:
# Document 1: american tower corporation and subsidiaries notes to consolidated financial statements 2014 ( continued ) 12 .impairments , net loss on sale of long-lived assets , restructuring and merger related expense the significant components reflected in impairments , net loss on sale of long-lived assets , restructuring and merger related expense in the accompanying consolidated statements of operations include the following : impairments and net loss on sale of long-lived assets 2014during the years ended december 31 , 2005 , 2004 and 2003 , the company recorded impairments and net loss on sale of long-lived assets ( primarily related to its rental and management segment ) of $ 19.1 million , $ 22.3 million and $ 28.3 million , respectively .2022 non-core asset impairment charges 2014during the years ended december 31 , 2005 and 2004 respectively , the company sold a limited number of non-core towers and other non-core assets and recorded impairment charges to write-down these and other
# Document 2: non-core assets to net realizable value .during the year ended december 31 , 2003 , the company sold approximately 300 non-core towers and certain other non-core assets and recorded impairment charges to write-down these and other non-core assets to net realizable value .as a result , the company recorded impairment charges and net losses of approximately $ 16.8 million , $ 17.7 million and $ 19.1 million for the years ended december 31 , 2005 , 2004 and 2003 , respectively .2022 construction-in-progress impairment charges 2014for the year ended december 31 , 2005 , 2004 and 2003 , the company wrote-off approximately $ 2.3 million , $ 4.6 million and $ 9.2 million , respectively , of construction-in-progress costs , primarily associated with sites that it no longer planned to build .restructuring expense 2014during the year ended december 31 , 2005 , the company made cash payments against its previous accrued restructuring liability in the amount of $ 0.8 million .during the year
# Document 3: net loss on sale of long-lived assets , restructuring and merger related expense the significant components reflected in impairments , net loss on sale of long-lived assets , restructuring and merger related expense in the accompanying consolidated statements of operations include the following : impairments and net loss on sale of long-lived assets 2014during the years ended december 31 , 2008 , 2007 and 2006 , the company recorded impairments and net loss on sale of long-lived assets ( primarily related to its rental and management segment ) of $ 11.2 million , $ 9.2 million and $ 2.6 million , respectively .during the years ended december 31 , 2008 , 2007 and 2006 respectively , the company recorded net losses associated with the sales of certain non-core towers and other assets , as well as impairment charges to write-down certain assets to net realizable value after an indicator of impairment had been identified .as a result , the company recorded net losses and impairments of
# Document 4: net loss on sale of long-lived assets , restructuring and merger related expense the significant components reflected in impairments , net loss on sale of long-lived assets , restructuring and merger related expense in the accompanying consolidated statements of operations include the following : impairments and net loss on sale of long-lived assets 2014during the years ended december 31 , 2008 , 2007 and 2006 , the company recorded impairments and net loss on sale of long-lived assets ( primarily related to its rental and management segment ) of $ 11.2 million , $ 9.2 million and $ 2.6 million , respectively .during the years ended december 31 , 2008 , 2007 and 2006 respectively , the company recorded net losses associated with the sales of certain non-core towers and other assets , as well as impairment charges to write-down certain assets to net realizable value after an indicator of impairment had been identified .as a result , the company recorded net losses and impairments of
# Document 5: 22.3 million , respectively .2022 non-core asset impairment charges 2014during the years ended december 31 , 2006 and 2005 respectively , the company recorded net losses associated with the sales of certain non-core towers and other assets , as well as impairment charges to write-down certain assets to net realizable value after an indicator of potential impairment had been identified .as a result , the company recorded net losses and impairments of approximately $ 2.0 million , $ 16.8 million and $ 17.7 million for the years ended december 31 , 2006 , 2005 and 2004 , respectively .the net loss for the year ended december 31 , 2006 is comprised net losses from asset sales and other impairments of $ 7.0 million , offset by gains from asset sales of $ 5.1 million .2022 construction-in-progress impairment charges 2014for the years ended december 31 , 2006 , 2005 and 2004 , the company wrote-off approximately $ 1.0 million , $ 2.3 million and $ 4.6 million , respectively , of
# Document 6: american tower corporation and subsidiaries notes to consolidated financial statements as of december 31 , 2012 , 2011 and 2010 , accumulated other comprehensive ( loss ) income included the following items related to derivative financial instruments ( in thousands ) : .
# Document 7: negatively affected by write-downs on highly leveraged finance commitments , alt-a mortgage revenue , write-downs on structured investment vehicles and commercial real estate , and mark-to-market on auction rate securities .total negative marks were $ 38.1 billion in 2008 as compared to $ 20.2 billion in 2007 , which are described in more detail below .operating expenses decreased 8% ( 8 % ) , mainly driven by lower compensation and transaction expenses .provisions for credit losses and for benefits and claims increased $ 2.7 billion , primarily due to a $ 2.2 billion increase in the reserve build and an increase in net credit losses of $ 0.5 billion .assets declined 31% ( 31 % ) versus the prior year , primarily driven by amortization and prepayments , sales , and marks and charge-offs. .
# Document 8: volumes and transaction expenses , partially offset by costs associated with the u.s .government loss-sharing agreement , which citi exited in the fourth quarter of 2009 .provisions for credit losses and for benefits and claims increased $ 1.5 billion , primarily driven by $ 4.5 billion in increased net credit losses , partially offset by a lower reserve build of $ 3.0 billion .assets declined 36% ( 36 % ) versus the prior year , primarily driven by amortization and prepayments , sales , marks and charge-offs .asset sales during the fourth quarter of 2009 ( $ 10 billion ) were executed at or above citi 2019s marks generating $ 800 million in pretax gains for the quarter .2008 vs .2007 revenues , net of interest expense decreased $ 21.7 billion , primarily due to negative net revenue marks .revenue included $ 14.3 billion of write- downs on subprime-related direct exposures and a negative $ 6.8 billion cva related to the monoline insurers and derivative positions .revenue was also
# Document 9: approximately $ 10.5 million , $ 7.1 million and $ 2.0 million for the years ended december 31 , 2008 , 2007 and 2006 , respectively .the net loss for the year ended december 31 , 2008 is comprised of net losses from asset sales and other impairments of $ 10.7 million , offset by gains from asset sales of $ 0.2 million .the net loss for the year ended december 31 , 2007 is comprised of net losses from asset sales and other impairments of $ 7.8 million , offset by gains from asset sales of $ 0.7 million .merger related expense 2014during the year ended december 31 , 2005 , the company assumed certain obligations , as a result of the merger with spectrasite , inc. , primarily related to employee separation costs of former spectrasite employees .severance payments made to former spectrasite , inc .employees were subject to plans and agreements established by spectrasite , inc .and assumed by the company in connection with the merger .these costs were recognized as an assumed liability in
# Document 10: approximately $ 10.5 million , $ 7.1 million and $ 2.0 million for the years ended december 31 , 2008 , 2007 and 2006 , respectively .the net loss for the year ended december 31 , 2008 is comprised of net losses from asset sales and other impairments of $ 10.7 million , offset by gains from asset sales of $ 0.2 million .the net loss for the year ended december 31 , 2007 is comprised of net losses from asset sales and other impairments of $ 7.8 million , offset by gains from asset sales of $ 0.7 million .merger related expense 2014during the year ended december 31 , 2005 , the company assumed certain obligations , as a result of the merger with spectrasite , inc. , primarily related to employee separation costs of former spectrasite employees .severance payments made to former spectrasite , inc .employees were subject to plans and agreements established by spectrasite , inc .and assumed by the company in connection with the merger .these costs were recognized as an assumed liability in

# %%
response = agentic_rag("as a result of the sales of certain non-core towers and other assets what was the recorded net losses of American Tower in 2008")
print(response.messages)
    
# Compute the score for the response
score = score_answer_chain.invoke({    
    'question': item['Question'],
    'answer': "10.5 million dollars",
    'response': response
}).score
print(score)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[155], line 2
#       1 response = agentic_rag("as a result of the sales of certain non-core towers and other assets what was the recorded net losses of American Tower in 2008")
# ----> 2 print(response.messages)
#       4 # Compute the score for the response
#       5 score = score_answer_chain.invoke({
#       6     'question': item['Question'],
#       7     'answer': "10.5 million dollars",
#       8     'response': response
#       9 }).score
#
# AttributeError: 'str' object has no attribute 'messages'
